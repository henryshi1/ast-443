# %%
### for array operations
import numpy as np

### for plotting
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
# %matplotlib inline

### for operations on FITS images
from astropy.io import fits

### statistics functions needed in this tutorial
from scipy import stats
from scipy.stats import norm

### change directory
import os

### for displaying graph (not very good but better than nothing)
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)
from astropy.visualization import simple_norm
### Curve fitting
from scipy.optimize import curve_fit

### glob glob
import glob

### for catalog file I/O
import pandas as pd

### for date/time manipulation and plotting
import datetime

### Time package.

from astropy.time import Time

# %% [markdown]
# 4.1
#
# 4.1.1 Master Darks

# %%
### Make all master darks for 10s, 12s, 20s

# Change to the darks directory
os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/DARKS')

### 10s master dark

# Open the 10s darks
hdu10sdark0 = fits.open('dark10s.00000000.DARK.FIT')
hdu10sdark1 = fits.open('dark10s.00000001.DARK.FIT')
hdu10sdark2 = fits.open('dark10s.00000002.DARK.FIT')
hdu10sdark3 = fits.open('dark10s.00000003.DARK.FIT')
hdu10sdark4 = fits.open('dark10s.00000004.DARK.FIT')
hdu10sdark5 = fits.open('dark10s.00000005.DARK.FIT')
hdu10sdark6 = fits.open('dark10s.00000006.DARK.FIT')
hdu10sdark7 = fits.open('dark10s.00000007.DARK.FIT')
hdu10sdark8 = fits.open('dark10s.00000008.DARK.FIT')
hdu10sdark9 = fits.open('dark10s.00000009.DARK.FIT')

# Extract the data arrays from the darks
image10sdata0 = hdu10sdark0[0].data
image10sdata1 = hdu10sdark1[0].data
image10sdata2 = hdu10sdark2[0].data
image10sdata3 = hdu10sdark3[0].data
image10sdata4 = hdu10sdark4[0].data
image10sdata5 = hdu10sdark5[0].data
image10sdata6 = hdu10sdark6[0].data
image10sdata7 = hdu10sdark7[0].data
image10sdata8 = hdu10sdark8[0].data
image10sdata9 = hdu10sdark9[0].data

# Take the median of the dark arrays
allimages10s=[image10sdata0,image10sdata1,image10sdata2,image10sdata3,image10sdata4,image10sdata5,image10sdata6,image10sdata7,image10sdata8,image10sdata9]

median10s = np.median(allimages10s, axis=0)

# Write to a master dark file output
masterdark10s = fits.PrimaryHDU(median10s)
masterdark10s.writeto('masterdark10s.fits', overwrite='overwrite')

### 12s master dark

# Open the 12s darks
hdu12sdark0 = fits.open('dark12s.00000000.DARK.FIT')
hdu12sdark1 = fits.open('dark12s.00000001.DARK.FIT')
hdu12sdark2 = fits.open('dark12s.00000002.DARK.FIT')
hdu12sdark3 = fits.open('dark12s.00000003.DARK.FIT')
hdu12sdark4 = fits.open('dark12s.00000004.DARK.FIT')
hdu12sdark5 = fits.open('dark12s.00000005.DARK.FIT')
hdu12sdark6 = fits.open('dark12s.00000006.DARK.FIT')
hdu12sdark7 = fits.open('dark12s.00000007.DARK.FIT')
hdu12sdark8 = fits.open('dark12s.00000008.DARK.FIT')
hdu12sdark9 = fits.open('dark12s.00000009.DARK.FIT')

# Extract the data arrays from the darks
image12sdata0 = hdu12sdark0[0].data
image12sdata1 = hdu12sdark1[0].data
image12sdata2 = hdu12sdark2[0].data
image12sdata3 = hdu12sdark3[0].data
image12sdata4 = hdu12sdark4[0].data
image12sdata5 = hdu12sdark5[0].data
image12sdata6 = hdu12sdark6[0].data
image12sdata7 = hdu12sdark7[0].data
image12sdata8 = hdu12sdark8[0].data
image12sdata9 = hdu12sdark9[0].data

# Take the median of the dark arrays
allimages12s=[image12sdata0,image12sdata1,image12sdata2,image12sdata3,image12sdata4,image12sdata5,image12sdata6,image12sdata7,image12sdata8,image12sdata9]

median12s = np.median(allimages12s, axis=0)

# Write to a master dark file output
masterdark12s = fits.PrimaryHDU(median12s)
masterdark12s.writeto('masterdark12s.fits', overwrite='overwrite')

### 20s master dark

# Open the 20s darks
hdu20sdark0 = fits.open('dark20s.00000000.DARK.FIT')
hdu20sdark1 = fits.open('dark20s.00000001.DARK.FIT')
hdu20sdark2 = fits.open('dark20s.00000002.DARK.FIT')
hdu20sdark3 = fits.open('dark20s.00000003.DARK.FIT')
hdu20sdark4 = fits.open('dark20s.00000004.DARK.FIT')
hdu20sdark5 = fits.open('dark20s.00000005.DARK.FIT')
hdu20sdark6 = fits.open('dark20s.00000006.DARK.FIT')
hdu20sdark7 = fits.open('dark20s.00000007.DARK.FIT')
hdu20sdark8 = fits.open('dark20s.00000008.DARK.FIT')
hdu20sdark9 = fits.open('dark20s.00000009.DARK.FIT')

# Extract the data arrays from the darks
image20sdata0 = hdu20sdark0[0].data
image20sdata1 = hdu20sdark1[0].data
image20sdata2 = hdu20sdark2[0].data
image20sdata3 = hdu20sdark3[0].data
image20sdata4 = hdu20sdark4[0].data
image20sdata5 = hdu20sdark5[0].data
image20sdata6 = hdu20sdark6[0].data
image20sdata7 = hdu20sdark7[0].data
image20sdata8 = hdu20sdark8[0].data
image20sdata9 = hdu20sdark9[0].data

# Take the median of the dark arrays
allimages20s=[image20sdata0,image20sdata1,image20sdata2,image20sdata3,image20sdata4,image20sdata5,image20sdata6,image20sdata7,image20sdata8,image20sdata9]

median20s = np.median(allimages20s, axis=0)

# Write to a master dark file output
masterdark20s = fits.PrimaryHDU(median20s)
masterdark20s.writeto('masterdark20s.fits', overwrite='overwrite')

# %% [markdown]
# 4.1.2 Master flat

# %%
# Change to the flats directory (Different for each computer)
os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/FLATS')

hduflat0 = fits.open('flat.00000000.FIT')
hduflat1 = fits.open('flat.00000001.FIT')
hduflat2 = fits.open('flat.00000002.FIT')
hduflat3 = fits.open('flat.00000003.FIT')
hduflat4 = fits.open('flat.00000004.FIT')
hduflat5 = fits.open('flat.00000005.FIT')
hduflat6 = fits.open('flat.00000006.FIT')
hduflat7 = fits.open('flat.00000007.FIT')
hduflat8 = fits.open('flat.00000008.FIT')
hduflat9 = fits.open('flat.00000009.FIT')

imageflat0 = hduflat0[0].data
imageflat1 = hduflat1[0].data
imageflat2 = hduflat2[0].data
imageflat3 = hduflat3[0].data
imageflat4 = hduflat4[0].data
imageflat5 = hduflat5[0].data
imageflat6 = hduflat6[0].data
imageflat7 = hduflat7[0].data
imageflat8 = hduflat8[0].data
imageflat9 = hduflat9[0].data

# Take the median of all flat fields
allflats=[imageflat0,imageflat1,imageflat2,imageflat3,imageflat4,imageflat5,imageflat6,imageflat7,imageflat8,imageflat9]

medianflat = np.median(allflats, axis=0)

# Normalize the median flat by dividing by the mode of counts
normflat = medianflat / stats.mode(medianflat.flatten())[0][0]

# Generate a master flat and write to file
masterflat = fits.PrimaryHDU(normflat)
masterflat.writeto('masterflat.fits', overwrite='overwrite')

# %% [markdown]
# # 4.2 Calibrated science images

# %% [markdown]
# 20 seconds

# %%
os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Calib20s')

for i in glob.glob('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Raw20s/science.0000*.FIT'):
    hduscience = fits.open(i)
    imagescience = hduscience[0].data
    calibscience = (imagescience - median20s) / normflat    # Calibrated science image = (raw - dark) / (flat)
    
    ### Annoying string manipulation to get file number
    prenumber = i.replace("/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Raw20s/science.","")
    number = prenumber.replace(".FIT", "")
    print(number)
    
    # Write the calibrated science image to file output with its corresponding image number
    calibscienceimage = fits.PrimaryHDU(calibscience)
    calibscienceimage.writeto('calibscience.' + number + '.fits', overwrite = 'overwrite')
print('Complete')

# /Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Calib20s/science.
# Out:
# 00000017
# 00000003
# 00000215
# 00000201
# 00000229
# 00000188
# 00000163
# 00000177
# 00000176
# 00000162
# 00000189
# 00000228
# 00000200
# 00000214
# 00000002
# 00000016
# 00000000
# 00000014
# 00000028
# 00000202
# 00000216
# 00000174
# 00000160
# 00000148
# 00000149
# 00000161
# 00000175
# 00000217
# 00000203
# 00000029
# 00000015
# 00000001
# 00000039
# 00000005
# 00000011
# 00000207
# 00000213
# 00000159
# 00000171
# 00000165
# 00000164
# 00000170
# 00000158
# 00000212
# 00000206
# 00000010
# 00000004
# 00000038
# 00000012
# 00000006
# 00000238
# 00000210
# 00000204
# 00000199
# 00000166
# 00000172
# 00000173
# 00000167
# 00000198
# 00000205
# 00000211
# 00000239
# 00000007
# 00000013
# 00000074
# 00000060
# 00000048
# 00000289
# 00000276
# 00000262
# 00000302
# 00000316
# 00000100
# 00000114
# 00000128
# 00000129
# 00000115
# 00000101
# 00000317
# 00000303
# 00000263
# 00000277
# 00000288
# 00000049
# 00000061
# 00000075
# 00000088
# 00000063
# 00000077
# 00000261
# 00000275
# 00000249
# 00000315
# 00000301
# 00000329
# 00000117
# 00000103
# 00000102
# 00000116
# 00000328
# 00000300
# 00000314
# 00000248
# 00000274
# 00000260
# 00000076
# 00000062
# 00000089
# 00000099
# 00000066
# 00000072
# 00000258
# 00000264
# 00000270
# 00000310
# 00000304
# 00000112
# 00000106
# 00000107
# 00000113
# 00000305
# 00000311
# 00000271
# 00000265
# 00000259
# 00000073
# 00000067
# 00000098
# 00000059
# 00000071
# 00000065
# 00000298
# 00000273
# 00000267
# 00000307
# 00000313
# 00000139
# 00000105
# 00000111
# 00000110
# 00000104
# 00000138
# 00000312
# 00000306
# 00000266
# 00000272
# 00000299
# 00000064
# 00000070
# 00000058
# 00000096
# 00000082
# 00000055
# 00000041
# 00000069
# 00000294
# 00000280
# 00000257
# 00000243
# 00000323
# 00000121
# 00000135
# 00000109
# 00000108
# 00000134
# 00000120
# 00000322
# 00000242
# 00000256
# 00000281
# 00000295
# 00000068
# 00000040
# 00000054
# 00000083
# 00000097
# 00000081
# 00000095
# 00000042
# 00000056
# 00000283
# 00000297
# 00000240
# 00000254
# 00000268
# 00000334
# 00000320
# 00000308
# 00000136
# 00000122
# 00000123
# 00000137
# 00000309
# 00000321
# 00000269
# 00000255
# 00000241
# 00000296
# 00000282
# 00000057
# 00000043
# 00000094
# 00000080
# 00000084
# 00000090
# 00000047
# 00000053
# 00000286
# 00000292
# 00000279
# 00000245
# 00000251
# 00000319
# 00000331
# 00000325
# 00000133
# 00000127
# 00000126
# 00000132
# 00000324
# 00000318
# 00000250
# 00000244
# 00000278
# 00000293
# 00000287
# 00000052
# 00000046
# 00000091
# 00000085
# 00000093
# 00000087
# 00000078
# 00000050
# 00000044
# 00000291
# 00000285
# 00000252
# 00000246
# 00000326
# 00000332
# 00000118
# 00000124
# 00000130
# 00000131
# 00000125
# 00000119
# 00000327
# 00000247
# 00000253
# 00000284
# 00000290
# 00000045
# 00000051
# 00000079
# 00000086
# 00000092
# 00000036
# 00000022
# 00000234
# 00000220
# 00000208
# 00000181
# 00000195
# 00000142
# 00000156
# 00000157
# 00000143
# 00000194
# 00000180
# 00000209
# 00000221
# 00000235
# 00000023
# 00000037
# 00000021
# 00000035
# 00000009
# 00000223
# 00000237
# 00000196
# 00000182
# 00000155
# 00000141
# 00000169
# 00000168
# 00000140
# 00000154
# 00000183
# 00000197
# 00000236
# 00000222
# 00000008
# 00000034
# 00000020
# 00000018
# 00000024
# 00000030
# 00000226
# 00000232
# 00000193
# 00000187
# 00000178
# 00000150
# 00000144
# 00000145
# 00000151
# 00000179
# 00000186
# 00000192
# 00000233
# 00000227
# 00000031
# 00000025
# 00000019
# 00000033
# 00000027
# 00000219
# 00000231
# 00000225
# 00000184
# 00000190
# 00000147
# 00000153
# 00000152
# 00000146
# 00000191
# 00000185
# 00000224
# 00000230
# 00000218
# 00000026
# 00000032
# Complete

# %% [markdown]
# 10 second

# %%
# Directory where we output calibrated science images
os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Calib10s')

# Take in the raw science images
for i in glob.glob('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Raw10s/science.0000*.FIT'):
    hduscience = fits.open(i)
    imagescience = hduscience[0].data
    calibscience = (imagescience - median10s) / normflat    # Calibrated science image = (raw - dark) / (flat)
    
    ### Annoying string manipulation to get file number
    prenumber = i.replace("/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Raw10s/science.","")
    number = prenumber.replace(".FIT", "")
    print(number)
    
    # Write the calibrated science image to file output with its corresponding image number
    calibscienceimage = fits.PrimaryHDU(calibscience)
    calibscienceimage.writeto('calibscience.' + number + '.fits', overwrite = 'overwrite')
print('Complete')
# Out:
# 00000407
# 00000361
# 00000375
# 00000413
# 00000349
# 00000348
# 00000374
# 00000412
# 00000406
# 00000360
# 00000389
# 00000410
# 00000376
# 00000362
# 00000404
# 00000438
# 00000439
# 00000363
# 00000405
# 00000411
# 00000377
# 00000388
# 00000398
# 00000429
# 00000373
# 00000415
# 00000401
# 00000367
# 00000400
# 00000366
# 00000372
# 00000414
# 00000428
# 00000399
# 00000358
# 00000364
# 00000402
# 00000416
# 00000370
# 00000417
# 00000371
# 00000365
# 00000403
# 00000359
# 00000338
# 00000339
# 00000449
# 00000448
# 00000445
# 00000337
# 00000450
# 00000336
# 00000444
# 00000452
# 00000446
# 00000447
# 00000335
# 00000443
# 00000442
# 00000330
# 00000440
# 00000441
# 00000383
# 00000397
# 00000426
# 00000340
# 00000354
# 00000432
# 00000368
# 00000369
# 00000355
# 00000433
# 00000427
# 00000341
# 00000396
# 00000382
# 00000394
# 00000380
# 00000431
# 00000357
# 00000343
# 00000425
# 00000419
# 00000418
# 00000342
# 00000424
# 00000430
# 00000356
# 00000381
# 00000395
# 00000391
# 00000385
# 00000408
# 00000352
# 00000434
# 00000420
# 00000346
# 00000421
# 00000347
# 00000353
# 00000435
# 00000409
# 00000384
# 00000390
# 00000386
# 00000392
# 00000379
# 00000345
# 00000423
# 00000437
# 00000351
# 00000436
# 00000350
# 00000344
# 00000422
# 00000378
# 00000393
# 00000387
# Complete

# %% [markdown]
# 12 second

# %%
# Directory where we output calibrated science images
os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Calib12s')

# Take in the raw science images
for i in glob.glob('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Raw12s/science.0000*.FIT'):
    hduscience = fits.open(i)
    imagescience = hduscience[0].data
    calibscience = (imagescience - median12s) / normflat
    
    ### Annoying string manipulation to get file number
    prenumber = i.replace("/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Raw12s/science.","")
    number = prenumber.replace(".FIT", "")
    print(number)
    
    # Write the calibrated science image to file output with its corresponding image number
    calibscienceimage = fits.PrimaryHDU(calibscience)
    calibscienceimage.writeto('calibscience.' + number + '.fits', overwrite = 'overwrite')
print('Complete')
# Out:
# 00000598
# 00000573
# 00000567
# 00000605
# 00000604
# 00000566
# 00000572
# 00000599
# 00000564
# 00000570
# 00000558
# 00000606
# 00000559
# 00000571
# 00000565
# 00000549
# 00000561
# 00000575
# 00000603
# 00000602
# 00000574
# 00000560
# 00000548
# 00000589
# 00000576
# 00000562
# 00000600
# 00000601
# 00000563
# 00000577
# 00000588
# 00000510
# 00000504
# 00000538
# 00000464
# 00000470
# 00000458
# 00000459
# 00000471
# 00000465
# 00000539
# 00000505
# 00000511
# 00000507
# 00000513
# 00000498
# 00000473
# 00000467
# 00000466
# 00000472
# 00000499
# 00000512
# 00000506
# 00000502
# 00000516
# 00000489
# 00000476
# 00000462
# 00000463
# 00000477
# 00000488
# 00000517
# 00000503
# 00000529
# 00000515
# 00000501
# 00000461
# 00000475
# 00000474
# 00000460
# 00000500
# 00000514
# 00000528
# 00000531
# 00000525
# 00000519
# 00000486
# 00000492
# 00000479
# 00000478
# 00000493
# 00000487
# 00000518
# 00000524
# 00000530
# 00000526
# 00000532
# 00000491
# 00000485
# 00000453
# 00000484
# 00000490
# 00000533
# 00000527
# 00000523
# 00000537
# 00000494
# 00000480
# 00000457
# 00000456
# 00000481
# 00000495
# 00000536
# 00000522
# 00000508
# 00000534
# 00000520
# 00000483
# 00000497
# 00000468
# 00000454
# 00000455
# 00000469
# 00000496
# 00000482
# 00000521
# 00000535
# 00000509
# 00000591
# 00000585
# 00000552
# 00000546
# 00000547
# 00000553
# 00000584
# 00000590
# 00000586
# 00000592
# 00000545
# 00000551
# 00000579
# 00000578
# 00000550
# 00000544
# 00000593
# 00000587
# 00000583
# 00000597
# 00000568
# 00000540
# 00000554
# 00000555
# 00000541
# 00000569
# 00000596
# 00000582
# 00000594
# 00000580
# 00000557
# 00000543
# 00000542
# 00000556
# 00000581
# 00000595
# Complete

# %% [markdown]
# # 4.3 Aperture Photometry

# %% [markdown]
# We set an aperture radius of $0.0022056^\circ = 0.13234' = 7.940$. It is the aperture.reg filename in the SCIENCE! directory for Lab 2.

# %% [markdown]
# We take in all the .cat files and extract the rows where the first two entries (RA, Dec) are within a $0.002^\circ$ distance of the "accepted" values, i.e. our science star and our 10 reference stars.

# %%
os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!')

# star coordinates
RA_sci = 300.1821377893 
Dec_sci = 22.7108620083

# These star coordinates are out of image bounds
# RA_ref1 = 300.0871477393
# Dec_ref1 = 22.4400420911

RA_ref1 = 300.2006625911
Dec_ref1 = 22.8033900511

RA_ref2 = 300.2373005925
Dec_ref2 = 22.8469786017

RA_ref3 = 300.0255854048
Dec_ref3 = 22.7048857522

# These star coordinates are out of image bounds
# RA_ref4 = 300.4540253700
# Dec_ref4 = 22.5656209922

# RA_ref5 = 300.4627377033
# Dec_ref5 = 22.7335455803

# RA_ref4 = 300.0600272951
# Dec_ref4 = 22.8632668425

RA_ref4 = 300.1348884260
Dec_ref4 = 22.8800385500

RA_ref5 = 300.0982684398 
Dec_ref5 = 22.6508175166

RA_ref6 = 300.1777196204
Dec_ref6 = 22.5748386467

RA_ref7 = 300.0488708985
Dec_ref7 = 22.7129936211

RA_ref8 = 300.2943370525
Dec_ref8 = 22.8327528650

RA_ref9 = 300.2453143524
Dec_ref9 = 22.6852492967

RA_ref10 = 300.1225019190
Dec_ref10 = 22.5723974375

# %%
# Table of flux, flux error, and observation times for science star
# and reference stars, separated by exposure time
sci_flux_table = []
ref1_flux_table = []
ref2_flux_table = []
ref3_flux_table = []
ref4_flux_table = []
ref5_flux_table = []
ref6_flux_table = []
ref7_flux_table = []
ref8_flux_table = []
ref9_flux_table = []
ref10_flux_table = []

### Loop begins here ###

for file_num in range(0,607):
    # file_num = Current science image number (to be looped over)
    
    ### Observation time ###

    # Change to our root directory at the start of every loop
    os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!')

    # Generate raw and calibrated science image filenames based on file_num
    if (file_num < 10):     # 1-digit file_num
        raw_name = 'science.00000' + '00' + str(file_num) + '.FIT'
        cal_name = 'calibscience.00000' + '00' + str(file_num) + '.fits.cat'
    elif (file_num < 100):  # 2-digit file_num
        raw_name = 'science.00000' + '0' + str(file_num) + '.FIT'
        cal_name = 'calibscience.00000' + '0' + str(file_num) + '.fits.cat'
    else:                   # 3-digit file_num
        raw_name = 'science.00000' + str(file_num) + '.FIT'
        cal_name = 'calibscience.00000' + str(file_num) + '.fits.cat'

    ### Observation times ###
    # Change to raw images directory
    os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/RAW')

    # Skip current loop iteration if file doesn't exist
    # print(os.path.exists(raw_name)) # Indeed, these raw_names pair up to all files (with one or two exceptions, analysis stuff) in RAW.
    if not os.path.exists(raw_name):
        continue # Returns loop to beginning if the file does not exist.
    
    # Read in the observation time from the header of the raw science image
    with fits.open(raw_name) as hdu1:
        obs_time = hdu1[0].header['DATE-OBS']
        obs_time = datetime.datetime.strptime(obs_time,'%Y-%m-%dT%H:%M:%S.%f')
    
    ### Flux and flux error ###

    exp_time = 0    # Exposure time
    # Change into the correct calibrated images directory (decision tree)
    # and set the exposure time variable accordingly
    if (file_num >= 452):   # Calib12s (file numbers 452-606)
        os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Calib12s')
        exp_time = 12
    elif (file_num >= 335): # Calib10s (file numbers 340-451)
        os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Calib10s')
        exp_time = 10
    else:                   # Calib20s (file numbers 001-)
        os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Calib20s')
        exp_time = 20
    
    # Skip current loop iteration if file doesn't exist
    # print(cal_name)
    # print(os.path.exists(cal_name)) # JUST SANITY CHECKS.
    if not os.path.exists(cal_name):
        # print(cal_name, 'not found.')
        continue

    # print the file names
    # print(raw_name,cal_name)

    # Read in the csv file using Pandas Dataframe
    df1 = pd.read_csv(cal_name, delim_whitespace=True, skiprows=18, header=None)
    # print(df1)

    # Loop through every row in the dataframe and extract values from row corresponding to our star
    # This loop will only happen if both the raw and calibrated filenames exist
    for index, row in df1.iterrows():
        # Extract the right ascension and declination
        RA = row.iloc[3]
        Dec = row.iloc[4]
        # print(RA,Dec)

        # Identify our science star, within 5 pixel values (0.002 degrees) of the "true" coordinates
        if ((RA - RA_sci)**2 + (Dec - Dec_sci)**2 < 0.002**2):
            # print(row)
            flux = row.iloc[5]/exp_time
            flux_err = row.iloc[6]/exp_time
            print(flux,flux_err)

            # Append the time, flux, and flux error to a list
            sci_flux_table.append([file_num, RA, Dec, obs_time, flux, flux_err])

        # Reference star #1
        elif ((RA - RA_ref1)**2 + (Dec - Dec_ref1)**2 < 0.002**2):
            # print(row)
            flux = row.iloc[5]/exp_time
            flux_err = row.iloc[6]/exp_time
            # print(flux,flux_err)

            # Append the time, flux, and flux error to a list
            ref1_flux_table.append([file_num, RA, Dec, obs_time, flux, flux_err])

        # Reference star #2
        elif ((RA - RA_ref2)**2 + (Dec - Dec_ref2)**2 < 0.002**2):
            # print(row)
            flux = row.iloc[5]/exp_time
            flux_err = row.iloc[6]/exp_time
            # print(flux,flux_err)

            # Append the time, flux, and flux error to a list
            ref2_flux_table.append([file_num, RA, Dec, obs_time, flux, flux_err])

        # Reference star #3
        elif ((RA - RA_ref3)**2 + (Dec - Dec_ref3)**2 < 0.002**2):
            # print(row)
            flux = row.iloc[5]/exp_time
            flux_err = row.iloc[6]/exp_time
            # print(flux,flux_err)

            # Append the time, flux, and flux error to a list
            ref3_flux_table.append([file_num, RA, Dec, obs_time, flux, flux_err])

        # Reference star #4
        elif ((RA - RA_ref4)**2 + (Dec - Dec_ref4)**2 < 0.002**2):
            # print(row)
            flux = row.iloc[5]/exp_time
            flux_err = row.iloc[6]/exp_time
            # print(flux,flux_err)

            # Append the time, flux, and flux error to a list
            ref4_flux_table.append([file_num, RA, Dec, obs_time, flux, flux_err])

        # Reference star #5
        elif ((RA - RA_ref5)**2 + (Dec - Dec_ref5)**2 < 0.002**2):
            # print(row)
            flux = row.iloc[5]/exp_time
            flux_err = row.iloc[6]/exp_time
            # print(flux,flux_err)

            # Append the time, flux, and flux error to a list
            ref5_flux_table.append([file_num, RA, Dec, obs_time, flux, flux_err])

        # Reference star #6
        elif ((RA - RA_ref6)**2 + (Dec - Dec_ref6)**2 < 0.002**2):
            # print(row)
            flux = row.iloc[5]/exp_time
            flux_err = row.iloc[6]/exp_time
            # print(flux,flux_err)

            # Append the time, flux, and flux error to a list
            ref6_flux_table.append([file_num, RA, Dec, obs_time, flux, flux_err])

        # Reference star #7
        elif ((RA - RA_ref7)**2 + (Dec - Dec_ref7)**2 < 0.002**2):
            # print(row)
            flux = row.iloc[5]/exp_time
            flux_err = row.iloc[6]/exp_time
            # print(flux,flux_err)

            # Append the time, flux, and flux error to a list
            ref7_flux_table.append([file_num, RA, Dec, obs_time, flux, flux_err])

        # Reference star #8
        elif ((RA - RA_ref8)**2 + (Dec - Dec_ref8)**2 < 0.002**2):
            # print(row)
            flux = row.iloc[5]/exp_time
            flux_err = row.iloc[6]/exp_time
            # print(flux,flux_err)

            # Append the time, flux, and flux error to a list
            ref8_flux_table.append([file_num, RA, Dec, obs_time, flux, flux_err])

        # Reference star #9
        elif ((RA - RA_ref9)**2 + (Dec - Dec_ref9)**2 < 0.002**2):
            # print(row)
            flux = row.iloc[5]/exp_time
            flux_err = row.iloc[6]/exp_time
            # print(flux,flux_err)

            # Append the time, flux, and flux error to a list
            ref9_flux_table.append([file_num, RA, Dec, obs_time, flux, flux_err])

        # Reference star #10
        elif ((RA - RA_ref10)**2 + (Dec - Dec_ref10)**2 < 0.002**2):
            # print(row)
            flux = row.iloc[5]/exp_time
            flux_err = row.iloc[6]/exp_time
            # print(flux,flux_err)

            # Append the time, flux, and flux error to a list
            ref10_flux_table.append([file_num, RA, Dec, obs_time, flux, flux_err])

print('Complete')
            
### Loop ends here ###
# Out:
# 12844.825 3.7058655000000003
# 10276.45 3.5989195
# 10251.225 3.6219755
# 10317.68 3.5977125
# 10302.055 3.6018909999999997
# 10275.130000000001 3.6059575
# 10276.460000000001 3.596031
# 10308.960000000001 3.6073009999999996
# 10307.965 3.6029015
# 10358.595 3.6100115
# 10366.189999999999 3.6126840000000002
# 10291.145 3.614542
# 10273.91 3.60683
# 10333.23 3.6007689999999997
# 10340.865 3.6079375
# 10362.795 3.597473
# 10268.39 3.6048769999999997
# 10338.4 3.5996375
# 10319.635 3.595478
# 10342.865 3.6172674999999996
# 10328.685000000001 3.6239885000000003
# 10314.91 3.6269959999999997
# 10321.135 3.6353445
# 10308.119999999999 3.6354415
# 10307.955 3.62995
# 10329.585000000001 3.614317
# 10344.86 3.623416
# 10371.14 3.637789
# 10339.61 3.627191
# 10343.84 3.6130555
# 10330.135 3.6175725
# 10308.289999999999 3.6098445
# 10360.73 3.6094904999999997
# 10362.58 3.6193750000000002
# 10287.61 3.6071485
# 10348.77 3.604907
# 10324.95 3.620946
# 10367.18 3.716672
# 10323.564999999999 3.6378234999999997
# 9843.695 3.6167050000000005
# 10332.0 3.610143
# 10381.77 3.6231815
# 10336.539999999999 3.6274515000000003
# 10330.135 3.616359
# 10334.955 3.6098765
# 10335.955 3.6017305
# 10322.98 3.5941895
# 10340.405 3.599785
# 10352.119999999999 3.603016
# 10381.414999999999 3.602516
# 10422.045 3.6024900000000004
# 10391.855 3.596585
# 10347.119999999999 3.601719
# 10331.885 3.609968
# 10330.735 3.599875
# 10365.9 3.5973835000000003
# 10358.814999999999 3.6119174999999997
# 10340.84 3.610322
# 10341.265 3.6144635000000003
# 10390.255000000001 3.606429
# 10349.1 3.612081
# 10334.175 3.604904
# 10352.560000000001 3.608823
# 10338.015 3.6146845
# 10342.585000000001 3.6117310000000002
# 10352.885 3.6006295
# 10338.53 3.5937965
# 10352.855 3.6107325
# 10353.3 3.6025
# 10413.955 3.6086945
# 10348.164999999999 3.61715
# 10332.375 3.619941
# 10330.35 3.6101585
# 10356.155 3.6199489999999996
# 10377.93 3.620968
# 10338.265 3.6187935
# 10333.5 3.6033655
# 10350.914999999999 3.6152445
# 10386.414999999999 3.6166964999999998
# 10304.189999999999 3.6038355
# 10385.465 3.6051580000000003
# 10333.11 3.5932070000000005
# 10354.685000000001 3.612787
# 10355.445 3.614307
# 10296.625 3.6064415
# 10333.994999999999 3.613955
# 10312.689999999999 3.618961
# 10332.560000000001 3.6198995
# 10336.11 3.6071685
# 10383.145 3.6217115
# 10385.07 3.6182795
# 10433.310000000001 3.6013125
# 10393.76 3.615544
# 10342.735 3.6109205
# 10356.795 3.6073180000000002
# 10392.45 3.6161454999999996
# 10370.705 3.606466
# 10347.555 3.6213360000000003
# 10347.55 3.6153585
# 10332.505000000001 3.6198900000000003
# 10325.42 3.619946
# 10409.975 3.611457
# 10365.875 3.6188209999999996
# 10355.255000000001 3.6155295
# 10347.11 3.6286955
# 10341.405 3.609292
# 10338.115 3.6112900000000003
# 10316.085000000001 3.6222645
# 10365.555 3.610716
# 10349.380000000001 3.6038474999999996
# 10284.619999999999 3.6238639999999998
# 10275.985 3.6122755
# 10275.59 3.621332
# 10344.08 3.622077
# 10351.405 3.6113085
# 10261.3 3.6102220000000003
# 10293.975 3.6149324999999997
# 10339.36 3.6246169999999998
# 10292.11 3.6120399999999995
# 10295.75 3.6243814999999997
# 10259.685000000001 3.6186095000000003
# 10322.195 3.6153264999999997
# 10254.855 3.6235045
# 10274.105 3.6094169999999997
# 10341.22 3.6184184999999998
# 10276.6 3.61565
# 10219.17 3.6149335000000002
# 10308.36 3.6381205000000003
# 10188.355 3.6080195
# 10214.869999999999 3.6313435
# 10172.615 3.6213205000000004
# 10224.125 3.618696
# 10220.61 3.621302
# 10244.72 3.6061895
# 10241.32 3.6224235
# 10204.07 3.6191575
# 10194.905 3.632087
# 10177.615 3.6227935
# 10193.07 3.6210575
# 10211.26 3.624393
# 10240.210000000001 3.6241275
# 10187.825 3.6183875
# 10133.135 3.6222374999999998
# 10166.414999999999 3.6252245000000003
# 10152.675 3.6174169999999997
# 10176.494999999999 3.612353
# 10136.175 3.6305715
# 10119.119999999999 3.6124720000000003
# 10193.78 3.629374
# 10134.72 3.6081429999999997
# 10160.515 3.61721
# 10096.975 3.633981
# 10109.45 3.6170540000000004
# 10134.735 3.6177225
# 10103.86 3.6174714999999997
# 10155.325 3.6130229999999997
# 10044.2 3.6176180000000002
# 10134.43 3.6202154999999996
# 10105.755000000001 3.6367095
# 10054.33 3.6270119999999997
# 10141.025 3.623834
# 10027.52 3.612782
# 10095.805 3.621833
# 10061.74 3.615856
# 10066.175 3.603836
# 10065.289999999999 3.6015070000000002
# 10056.83 3.6211305000000005
# 10079.105 3.6113259999999996
# 10065.335000000001 3.6165469999999997
# 10085.77 3.6127434999999997
# 10052.135 3.620432
# 10101.210000000001 3.6048470000000004
# 10046.235 3.6028395000000004
# 10062.905 3.6110169999999995
# 10079.45 3.6174120000000003
# 10077.1 3.6211075
# 10052.335000000001 3.6109769999999997
# 10010.635 3.6231275
# 10066.175 3.614776
# 10090.53 3.633268
# 10069.435000000001 3.6252969999999998
# 10053.32 3.6154265000000003
# 10103.380000000001 3.617355
# 10042.414999999999 3.6245985
# 10053.51 3.6124229999999997
# 10045.814999999999 3.6317115
# 10084.3 3.6295285
# 10082.635 3.6286095000000005
# 10025.42 3.6111905
# 10042.025 3.6109074999999997
# 10083.9 3.6106205000000005
# 10028.28 3.6220665
# 10051.89 3.6137430000000004
# 10067.405 3.630943
# 10106.695 3.627017
# 10045.35 3.6222380000000003
# 10060.89 3.6206975
# 10022.385 3.6142515000000004
# 10047.095 3.6103615
# 10038.210000000001 3.6153619999999997
# 10078.85 3.623666
# 10040.164999999999 3.6129515
# 10070.48 3.6101750000000004
# 10052.275 3.6373334999999996
# 10007.01 3.6091504999999997
# 10047.49 3.606102
# 10061.215 3.621929
# 10072.845 3.624999
# 9990.45 3.6215249999999997
# 10044.89 3.6327385
# 9934.244999999999 3.6299855
# 10008.085000000001 3.6265994999999998
# 10007.715 3.6259155
# 10019.22 3.6177504999999996
# 10018.189999999999 3.630145
# 9967.35 3.6223199999999998
# 10021.34 3.6257495
# 9958.43 3.6465069999999997
# 10023.43 3.637625
# 10027.494999999999 3.6173335
# 9989.08 3.6279665000000003
# 10022.59 3.612769
# 9952.445 3.62213
# 9983.97 3.6220685
# 10021.675 3.6276015
# 10005.4 3.6196275
# 10005.869999999999 3.6159689999999998
# 9999.78 3.628812
# 9964.97 3.6275734999999996
# 10019.985 3.6205985
# 9982.86 3.6251075
# 9987.305 3.6239035
# 10016.085000000001 3.6246389999999997
# 9988.795 3.6332165000000005
# 10005.0 3.6217165000000002
# 9959.98 3.625938
# 9970.275 3.631742
# 9954.439999999999 3.620082
# 9979.210000000001 3.6419535000000005
# 9912.535 3.6273345
# 9900.485 3.6311504999999995
# 9969.74 3.6326009999999997
# 9949.765 3.6196244999999996
# 9966.914999999999 3.6169375
# 9907.835000000001 3.6155904999999997
# 9923.89 3.6155245000000003
# 9987.630000000001 3.633721
# 9974.76 3.6403655
# 9939.895 3.6386450000000004
# 9927.285 3.6230435
# 9933.560000000001 3.625902
# 9952.810000000001 3.6290104999999997
# 9911.355 3.6242905
# 9926.2 3.621657
# 9961.08 3.6407645000000004
# 9924.42 3.6189585
# 9873.939999999999 3.627939
# 9867.82 3.6108355000000003
# 9905.5 3.6274284999999997
# 9930.205 3.645284
# 9942.3 3.6248199999999997
# 9889.45 3.6280845
# 9916.76 3.6168835
# 9934.130000000001 3.6228185
# 9895.385 3.6288519999999997
# 9848.564999999999 3.6341810000000003
# 9877.785 3.6256125
# 9880.175 3.6400284999999997
# 9879.625 3.6172139999999997
# 9914.91 3.6351205
# 9922.0 3.6207374999999997
# 9852.41 3.629562
# 9896.685000000001 3.6237265
# 9858.869999999999 3.6229394999999998
# 9890.189999999999 3.6326365000000003
# 9905.55 3.6242080000000003
# 9964.125 3.6237975
# 9933.18 3.6115090000000003
# 9900.68 3.6150945
# 9952.175 3.6240634999999997
# 9904.994999999999 3.6170245000000003
# 9924.369999999999 3.622399
# 9936.055 3.6133584999999995
# 9848.695 3.620817
# 9896.064999999999 3.605062
# 9890.560000000001 3.6280135000000002
# 9887.59 3.6227834999999997
# 9910.76 3.6248294999999997
# 9876.060000000001 3.624035
# 9929.310000000001 3.6204434999999995
# 9874.36 3.6279085
# 9895.33 3.641845
# 9836.64 3.6324855
# 9902.130000000001 3.6256320000000004
# 9832.67 3.623254
# 9939.935000000001 3.631064
# 9863.369999999999 3.619914
# 9933.525 3.6257620000000004
# 9901.73 3.626352
# 9945.785 3.615455
# 10001.865 3.62572
# 9888.310000000001 3.6246085
# 9980.119999999999 3.6185634999999996
# 9925.380000000001 3.6192245
# 9862.26 3.6313515
# 9980.060000000001 3.613884
# 9919.805 3.628196
# 10011.045 3.6301634999999997
# 9984.115 3.624221
# 9928.905 3.621846
# 9957.025 3.6236040000000003
# 9975.66 3.6373945
# 10008.225 3.6463855
# 9998.89 3.6296385
# 10022.76 3.6146795
# 9978.555 3.624835
# 10010.045 3.6411904999999996
# 10008.28 3.6614400000000002
# 10035.68 3.6245545
# 10058.555 3.6317709999999996
# 10004.72 3.63279
# 10016.395 3.6431489999999997
# 10041.305 3.6316405000000005
# 10098.73 3.6352155
# 10063.76 3.6344745000000005
# 10067.814999999999 3.6468654999999996
# 10093.605 3.6284625
# 10053.914999999999 3.6230365
# 10089.68 3.63669
# 10083.49 3.6302844999999997
# 10075.875 3.6324309999999995
# 10097.564999999999 3.6306885
# 10164.505000000001 3.6475549999999997
# 10071.09 6.931502999999999
# 10072.0 6.952047
# 10190.75 6.921304000000001
# 10072.119999999999 6.949235
# 10139.33 6.953336
# 10056.130000000001 6.917261000000001
# 10001.58 6.929316
# 9983.966 6.935024
# 10034.42 6.936297999999999
# 9971.178 6.932053000000001
# 10089.99 6.943998000000001
# 10019.8 6.945084
# 10074.060000000001 6.9285499999999995
# 10044.810000000001 6.942145999999999
# 10006.91 6.947595
# 9948.564 6.925603
# 10003.39 6.938028
# 9823.428 6.936179
# 10014.9 6.951220999999999
# 10087.22 6.954573999999999
# 9960.155 6.9512339999999995
# 9877.511999999999 6.953441
# 10025.060000000001 6.941339999999999
# 10019.5 6.943557
# 9935.744 6.943803
# 10001.98 6.935184
# 9935.115 6.951924
# 9992.824 6.927193
# 9896.712 6.932259999999999
# 9987.869999999999 6.950683
# 10060.25 6.929273
# 9918.983 6.924889
# 9971.405 6.933541
# 9941.196 6.936169
# 10051.65 6.917203000000001
# 10116.43 6.955798
# 9889.766 6.931925
# 9944.179 6.943975
# 9971.52 6.948241
# 9991.212 6.951156
# 9945.130000000001 6.92282
# 9937.558 6.936967
# 9874.318 6.933623
# 9973.326 6.909026
# 10059.18 6.93665
# 9973.728 6.923792000000001
# 10052.4 6.961703
# 9942.332 6.94632
# 9978.572 6.933365
# 10102.710000000001 6.921514
# 9999.122 6.934594
# 9981.954 6.929698
# 9976.136 6.9458839999999995
# 9942.759 6.923331
# 9951.588 6.962054
# 9934.297999999999 6.9651629999999995
# 10089.47 6.932818
# 10015.619999999999 6.961817000000001
# 10000.72 6.963657
# 10036.11 6.926862
# 10000.24 6.945305
# 10016.07 6.926537000000001
# 9958.197 6.934504
# 9943.996000000001 6.957841999999999
# 9922.833 6.9146019999999995
# 9971.695 6.933338999999999
# 9963.106 6.943433000000001
# 10038.35 6.976399000000001
# 9977.252 6.929768
# 10045.23 6.945766000000001
# 9996.158 6.944521
# 10009.03 6.934413000000001
# 9953.633 6.937074
# 9898.417 6.936439
# 9942.538 6.9625140000000005
# 9997.757000000001 6.931579999999999
# 10013.51 6.954708999999999
# 9861.326 6.9311359999999995
# 10027.439999999999 6.918819999999999
# 10011.039999999999 6.937156
# 9949.060000000001 6.9583889999999995
# 10004.11 6.952146000000001
# 10016.539999999999 6.919363
# 9876.753 6.9396569999999995
# 9970.047 6.936957
# 10018.14 6.9560569999999995
# 9960.413 6.943521
# 9988.138 6.9399109999999995
# 9898.524000000001 6.925707
# 10121.59 6.915455
# 10019.97 6.971766
# 9915.945 6.949876000000001
# 9918.08 6.940495
# 9942.439999999999 6.940309999999999
# 10014.939999999999 6.936595
# 10095.24 6.928529
# 9863.725 6.955026999999999
# 10069.58 6.960309
# 9934.938 6.953647999999999
# 10046.75 6.935045
# 9926.909 6.942641999999999
# 9863.742999999999 6.947734
# 9979.547 6.950342999999999
# 9945.859 6.9559169999999995
# 9948.089 6.948404999999999
# 9924.907000000001 6.940424
# 10044.210000000001 6.935107
# 9920.211 6.936020999999999
# 9940.706 6.957333
# 9897.678 6.937563
# 9902.426 6.948605000000001
# 10012.35 6.948595
# 9988.455 6.93168
# 9952.475999999999 6.971585
# 9841.259 6.972102
# 9891.966666666667 5.839424166666666
# 9966.666666666666 5.829148333333333
# 9969.291666666666 5.825411666666667
# 9940.716666666667 5.843251666666667
# 9918.383333333333 5.828035
# 9950.566666666668 5.8304800000000006
# 9966.733333333334 5.830266666666667
# 10010.5 5.835963333333333
# 9995.783333333333 5.851119166666667
# 9845.091666666667 5.824328333333334
# 9935.050000000001 5.82848
# 9898.15 5.824818333333333
# 9966.791666666666 5.825038333333333
# 10013.908333333333 5.818643333333333
# 9960.358333333334 5.831411666666667
# 9978.199999999999 5.830004166666666
# 9956.866666666667 5.832215000000001
# 9995.316666666668 5.847849166666666
# 10032.433333333332 5.839194166666666
# 9931.9 5.8352233333333325
# 9948.983333333334 5.826058333333333
# 9882.866666666667 5.832345833333334
# 9967.891666666666 5.8116275
# 9949.008333333333 5.8478575
# 10002.466666666667 5.835635833333334
# 9915.366666666667 5.8077875
# 9927.258333333333 5.8464383333333325
# 9925.641666666666 5.836955833333334
# 9936.574999999999 5.833144166666667
# 9883.975 5.822359166666666
# 9859.541666666666 5.84113
# 9887.975 5.830010000000001
# 9932.733333333334 5.825640833333334
# 9885.791666666666 5.837387499999999
# 9910.975 5.849544166666667
# 9896.591666666667 5.822471666666666
# 9852.583333333334 5.8285475
# 10022.050000000001 5.8490125
# 9882.116666666667 5.846578333333333
# 9960.125 5.807700833333333
# 9830.241666666667 5.843934999999999
# 9929.050000000001 5.835250833333333
# 9957.6 5.832903333333333
# 9947.633333333333 5.8416508333333335
# 9892.574999999999 5.8425183333333335
# 9919.041666666666 5.8805000000000005
# 9894.608333333334 5.849805
# 9856.216666666667 5.848654166666667
# 9984.316666666668 5.8363933333333335
# 9856.841666666667 5.854498333333333
# 9850.533333333333 5.854035
# 9938.333333333334 5.8388675
# 9821.683333333332 5.85372
# 9870.208333333334 5.832589166666666
# 9838.866666666667 5.850276666666667
# 9832.6 5.847618333333333
# 9848.0 5.84823
# 9890.533333333333 5.849360833333333
# 9651.633333333333 5.8292633333333335
# 9771.041666666666 5.846665833333333
# 9874.508333333333 5.819520833333333
# 9879.591666666667 5.833023333333333
# 9701.949999999999 5.870486666666667
# 9652.283333333333 5.851263333333333
# 9793.083333333334 5.845925
# 9739.191666666668 5.841179166666667
# 9767.324999999999 5.8470949999999995
# 9771.050000000001 5.860006666666667
# 9698.591666666667 5.8368025
# 9814.216666666667 5.8431475
# 9733.15 5.8376925
# 9870.733333333334 5.837925833333333
# 9756.983333333334 5.861318333333333
# 9717.741666666667 5.8469083333333325
# 9798.041666666666 5.839905000000001
# 9700.933333333332 5.8554475
# 9772.35 5.822555
# 9764.625 5.838845
# 9814.85 5.832295833333333
# 9844.983333333334 5.8378958333333335
# 9709.125 5.827040833333334
# 9921.4 5.855995
# 9781.525 5.86393
# 9680.175000000001 5.857404166666666
# 9723.775 5.850204166666667
# 9721.275 5.860374166666666
# 9715.800000000001 5.847978333333334
# 9783.574999999999 5.866628333333334
# 9826.800000000001 5.852593333333334
# 9765.75 5.863793333333334
# 9888.958333333334 5.8509025
# 9754.375 5.8377475
# 9784.025 5.828185833333333
# 9942.358333333334 5.851325833333333
# 9724.125 5.849550833333333
# 9752.691666666668 5.865772499999999
# 9791.066666666668 5.8573200000000005
# 9717.808333333332 5.850501666666666
# 9773.975 5.886113333333333
# 9882.75 5.848459166666667
# 9768.683333333332 5.8502
# 9761.1 5.841195833333334
# 9714.449999999999 5.864565833333334
# 9712.183333333332 5.845305
# 9825.366666666667 5.845856666666666
# 9789.983333333334 5.8626775
# 9812.775 5.855283333333333
# 9896.641666666666 5.873815833333333
# 9715.0 5.861619999999999
# 9752.058333333332 5.867325833333333
# 9689.916666666666 5.85716
# 9798.158333333333 5.849410833333334
# 9807.175000000001 5.851039166666666
# 9749.591666666667 5.8595425
# 9782.050000000001 5.8496
# 9755.783333333333 5.8492283333333335
# 9724.5 5.86132
# 9667.158333333333 5.8611125
# 9747.791666666666 5.86105
# 9703.458333333334 5.8313525
# 9784.425000000001 5.876494166666667
# 9632.416666666666 5.858963333333333
# 9812.841666666667 5.8543475
# 9726.833333333334 5.848881666666667
# 9682.658333333333 5.850901666666666
# 9709.508333333333 5.8604125
# 9651.775 5.849535833333333
# 9730.983333333334 5.856834166666666
# 9701.0 5.8509400000000005
# 9645.725 5.8567375
# 9593.916666666666 5.861660833333333
# 9763.775 5.847700833333334
# 9691.508333333333 5.844056666666667
# 9736.016666666666 5.855149999999999
# 9725.258333333333 5.838728333333333
# 9676.491666666667 5.866314166666666
# 9732.841666666667 5.860908333333334
# 9670.316666666668 5.856871666666667
# 9620.433333333332 5.8643141666666665
# 9714.083333333334 5.859569166666667
# 9554.041666666666 5.884901666666667
# 9781.824999999999 5.850691666666666
# 9690.6 5.8563133333333335
# 9688.050000000001 5.834531666666667
# 9642.016666666666 5.862055000000001
# 9702.199999999999 5.8638525
# 9706.283333333333 5.8567775
# 9638.791666666666 5.8503058333333335
# 9741.066666666668 5.8642658333333335
# 9642.658333333333 5.842655833333333
# 9751.716666666667 5.8587983333333336
# 9732.383333333333 5.867299166666666
# 9654.758333333333 5.885025833333334
# 9649.441666666668 5.870439166666666
# 9675.65 5.864769166666666
# Complete

# %%
# Some sanity checks.

os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Calib20s')
print(os.path.exists('calibscience.00000333.fits.cat'))

os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Calib12s')
print(os.path.exists('calibscience.00000451.fits.cat'))
# Out:
# False
# False

# %%
# print(flux_table)

# Directory to output CSV files (flux tables)
os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/Analysis/Flux tables')

### Science star data frame ###

# Construct a new data frame with file index, coordinates, obs times, flux, and flux error
df_sci = pd.DataFrame(np.array(sci_flux_table), columns=['Index', 'RA', 'Dec', 'Obs time', 'Flux', 'Flux error'])
print(df_sci)

# Construct a condensed data frame with only obs times, flux, and flux error
df_sci_flux = df_sci[['Obs time', 'Flux', 'Flux error']]
print(df_sci_flux)

# Output the table of time, flux, and flux error for our star, as a csv file
df_sci_flux.to_csv('4.3_science_time_flux.csv')

### Reference stars data frames ###

# Reference star 1
df_ref1 = pd.DataFrame(np.array(ref1_flux_table), columns=['Index', 'RA', 'Dec', 'Obs time', 'Flux', 'Flux error'])

# Construct a condensed data frame with only obs times, flux, and flux error
df_ref1_flux = df_ref1[['Obs time', 'Flux', 'Flux error']]

# Output the table of time, flux, and flux error for our star, as a csv file
df_ref1_flux.to_csv('4.3_ref1_time_flux.csv')

# Reference star 2
df_ref2 = pd.DataFrame(np.array(ref2_flux_table), columns=['Index', 'RA', 'Dec', 'Obs time', 'Flux', 'Flux error'])

# Construct a condensed data frame with only obs times, flux, and flux error
df_ref2_flux = df_ref2[['Obs time', 'Flux', 'Flux error']]

# Output the table of time, flux, and flux error for our star, as a csv file
df_ref2_flux.to_csv('4.3_ref2_time_flux.csv')

# Reference star 3
df_ref3 = pd.DataFrame(np.array(ref3_flux_table), columns=['Index', 'RA', 'Dec', 'Obs time', 'Flux', 'Flux error'])

# Construct a condensed data frame with only obs times, flux, and flux error
df_ref3_flux = df_ref3[['Obs time', 'Flux', 'Flux error']]

# Output the table of time, flux, and flux error for our star, as a csv file
df_ref3_flux.to_csv('4.3_ref3_time_flux.csv')

# Reference star 4
df_ref4 = pd.DataFrame(np.array(ref4_flux_table), columns=['Index', 'RA', 'Dec', 'Obs time', 'Flux', 'Flux error'])

# Construct a condensed data frame with only obs times, flux, and flux error
df_ref4_flux = df_ref4[['Obs time', 'Flux', 'Flux error']]

# Output the table of time, flux, and flux error for our star, as a csv file
df_ref4_flux.to_csv('4.3_ref4_time_flux.csv')

# Reference star 5
df_ref5 = pd.DataFrame(np.array(ref5_flux_table), columns=['Index', 'RA', 'Dec', 'Obs time', 'Flux', 'Flux error'])

# Construct a condensed data frame with only obs times, flux, and flux error
df_ref5_flux = df_ref5[['Obs time', 'Flux', 'Flux error']]

# Output the table of time, flux, and flux error for our star, as a csv file
df_ref5_flux.to_csv('4.3_ref5_time_flux.csv')

# Reference star 6
df_ref6 = pd.DataFrame(np.array(ref6_flux_table), columns=['Index', 'RA', 'Dec', 'Obs time', 'Flux', 'Flux error'])

# Construct a condensed data frame with only obs times, flux, and flux error
df_ref6_flux = df_ref6[['Obs time', 'Flux', 'Flux error']]

# Output the table of time, flux, and flux error for our star, as a csv file
df_ref6_flux.to_csv('4.3_ref6_time_flux.csv')

# Reference star 7
df_ref7 = pd.DataFrame(np.array(ref7_flux_table), columns=['Index', 'RA', 'Dec', 'Obs time', 'Flux', 'Flux error'])

# Construct a condensed data frame with only obs times, flux, and flux error
df_ref7_flux = df_ref7[['Obs time', 'Flux', 'Flux error']]

# Output the table of time, flux, and flux error for our star, as a csv file
df_ref7_flux.to_csv('4.3_ref7_time_flux.csv')

# Reference star 8
df_ref8 = pd.DataFrame(np.array(ref8_flux_table), columns=['Index', 'RA', 'Dec', 'Obs time', 'Flux', 'Flux error'])

# Construct a condensed data frame with only obs times, flux, and flux error
df_ref8_flux = df_ref8[['Obs time', 'Flux', 'Flux error']]

# Output the table of time, flux, and flux error for our star, as a csv file
df_ref8_flux.to_csv('4.3_ref8_time_flux.csv')

# Reference star 9
df_ref9 = pd.DataFrame(np.array(ref9_flux_table), columns=['Index', 'RA', 'Dec', 'Obs time', 'Flux', 'Flux error'])

# Construct a condensed data frame with only obs times, flux, and flux error
df_ref9_flux = df_ref9[['Obs time', 'Flux', 'Flux error']]

# Output the table of time, flux, and flux error for our star, as a csv file
df_ref9_flux.to_csv('4.3_ref9_time_flux.csv')

# Reference star 8
df_ref10 = pd.DataFrame(np.array(ref10_flux_table), columns=['Index', 'RA', 'Dec', 'Obs time', 'Flux', 'Flux error'])

# Construct a condensed data frame with only obs times, flux, and flux error
df_ref10_flux = df_ref10[['Obs time', 'Flux', 'Flux error']]

# Output the table of time, flux, and flux error for our star, as a csv file
df_ref10_flux.to_csv('4.3_ref10_time_flux.csv')
# Out:
#     Index          RA        Dec                Obs time         Flux  \
# 0       0  300.182134  22.709241 2022-08-31 21:58:19.433    12844.825
# 1       1  300.182123   22.70925 2022-08-31 21:59:08.873     10276.45
# 2       2  300.182123  22.709261 2022-08-31 22:04:45.616    10251.225
# 3       3  300.182121  22.709243 2022-08-31 22:05:10.579     10317.68
# 4       4  300.182119   22.70926 2022-08-31 22:05:36.205    10302.055
# ..    ...         ...        ...                     ...          ...
# 598   602    300.1821   22.70925 2022-09-01 01:58:10.529  9751.716667
# 599   603  300.182093  22.709244 2022-09-01 01:58:27.817  9732.383333
# 600   604  300.182088  22.709257 2022-09-01 01:58:44.935  9654.758333
# 601   605  300.182108  22.709242 2022-09-01 01:59:02.089  9649.441667
# 602   606  300.182098  22.709234 2022-09-01 01:59:19.441      9675.65
#
#     Flux error
# 0     3.705866
# 1      3.59892
# 2     3.621976
# 3     3.597713
# 4     3.601891
# ..         ...
# 598   5.858798
# 599   5.867299
# 600   5.885026
# 601   5.870439
# 602   5.864769
#
# [603 rows x 6 columns]
#                    Obs time         Flux Flux error
# 0   2022-08-31 21:58:19.433    12844.825   3.705866
# 1   2022-08-31 21:59:08.873     10276.45    3.59892
# 2   2022-08-31 22:04:45.616    10251.225   3.621976
# 3   2022-08-31 22:05:10.579     10317.68   3.597713
# 4   2022-08-31 22:05:36.205    10302.055   3.601891
# ..                      ...          ...        ...
# 598 2022-09-01 01:58:10.529  9751.716667   5.858798
# 599 2022-09-01 01:58:27.817  9732.383333   5.867299
# 600 2022-09-01 01:58:44.935  9654.758333   5.885026
# 601 2022-09-01 01:59:02.089  9649.441667   5.870439
# 602 2022-09-01 01:59:19.441      9675.65   5.864769
#
# [603 rows x 3 columns]

# %%
print(np.array(sci_flux_table))
# Out:
# [[0 300.1821343 22.7092412
#   datetime.datetime(2022, 8, 31, 21, 58, 19, 433000) 12844.825
#   3.7058655000000003]
#  [1 300.1821233 22.7092496
#   datetime.datetime(2022, 8, 31, 21, 59, 8, 873000) 10276.45 3.5989195]
#  [2 300.1821228 22.7092611
#   datetime.datetime(2022, 8, 31, 22, 4, 45, 616000) 10251.225 3.6219755]
#  ...
#  [604 300.1820882 22.7092573
#   datetime.datetime(2022, 9, 1, 1, 58, 44, 935000) 9654.758333333333
#   5.885025833333334]
#  [605 300.1821081 22.7092415
#   datetime.datetime(2022, 9, 1, 1, 59, 2, 89000) 9649.441666666668
#   5.870439166666666]
#  [606 300.182098 22.7092338
#   datetime.datetime(2022, 9, 1, 1, 59, 19, 441000) 9675.65
#   5.864769166666666]]

# %%
print("science: ", len(sci_flux_table))
print("reference 1: ", len(ref1_flux_table))
print("reference 2: ", len(ref2_flux_table))
print("reference 3: ", len(ref3_flux_table))
print("reference 4: ", len(ref4_flux_table))
print("reference 5: ", len(ref5_flux_table))
print("reference 6: ", len(ref6_flux_table))
print("reference 7: ", len(ref7_flux_table))
print("reference 8: ", len(ref8_flux_table))
print("reference 9: ", len(ref9_flux_table))
print("reference 10: ", len(ref10_flux_table))
# Out:
# science:  603
# reference 1:  603
# reference 2:  603
# reference 3:  603
# reference 4:  603
# reference 5:  603
# reference 6:  603
# reference 7:  603
# reference 8:  603
# reference 9:  603
# reference 10:  603

# %% [markdown]
# # 4.4 Lightcurves of reference stars

# %% [markdown]
# First, we reuse the reference star flux data frames from 4.3. We find the average flux of all reference stars.

# %%
# Reference star 1

# Extract flux values
ref1_flux = df_ref1_flux['Flux'].to_numpy()
# Type cast as floats
ref1_flux = ref1_flux.astype(float)
# Calculate mean flux
ref1_mean_flux = np.mean(ref1_flux)

print(ref1_mean_flux)

# Reference star 2

ref2_flux = df_ref2_flux['Flux'].to_numpy()
ref2_flux = ref2_flux.astype(float)
ref2_mean_flux = np.mean(ref2_flux)

print(ref2_mean_flux)

# Reference star 3

ref3_flux = df_ref3_flux['Flux'].to_numpy()
ref3_flux = ref3_flux.astype(float)
ref3_mean_flux = np.mean(ref3_flux)

print(ref3_mean_flux)

# Reference star 4

ref4_flux = df_ref4_flux['Flux'].to_numpy()
ref4_flux = ref4_flux.astype(float)
ref4_mean_flux = np.mean(ref4_flux)

print(ref4_mean_flux)

# Reference star 5

ref5_flux = df_ref5_flux['Flux'].to_numpy()
ref5_flux = ref5_flux.astype(float)
ref5_mean_flux = np.mean(ref5_flux)

print(ref5_mean_flux)

# Reference star 6

ref6_flux = df_ref6_flux['Flux'].to_numpy()
ref6_flux = ref6_flux.astype(float)
ref6_mean_flux = np.mean(ref6_flux)

print(ref6_mean_flux)

# Reference star 7

ref7_flux = df_ref7_flux['Flux'].to_numpy()
ref7_flux = ref7_flux.astype(float)
ref7_mean_flux = np.mean(ref7_flux)

print(ref7_mean_flux)

# Reference star 8

ref8_flux = df_ref8_flux['Flux'].to_numpy()
ref8_flux = ref8_flux.astype(float)
ref8_mean_flux = np.mean(ref8_flux)

print(ref8_mean_flux)

# Reference star 9

ref9_flux = df_ref9_flux['Flux'].to_numpy()
ref9_flux = ref9_flux.astype(float)
ref9_mean_flux = np.mean(ref9_flux)

print(ref9_mean_flux)

# Reference star 10

ref10_flux = df_ref10_flux['Flux'].to_numpy()
ref10_flux = ref10_flux.astype(float)
ref10_mean_flux = np.mean(ref10_flux)

print(ref10_mean_flux)

# Science star

sci_flux = df_sci_flux['Flux'].to_numpy()
sci_flux = sci_flux.astype(float)
sci_mean_flux = np.mean(sci_flux)

print(sci_mean_flux)
print(sci_flux)
print(sci_flux_err)
# Out:
# 463.68101995577666
# 7294.125519347706
# 2642.7793200663355
# 561.6943904643449
# 449.71829016030955
# 1466.9417669983418
# 1552.7597429519071
# 615.2142954671089
# 910.9183893864013
# 374.13434405749035
# 10027.581134881151
# [12844.825      10276.45       10251.225      10317.68
#  10302.055      10275.13       10276.46       10308.96
#  10307.965      10358.595      10366.19       10291.145
#  10273.91       10333.23       10340.865      10362.795
#  10268.39       10338.4        10319.635      10342.865
#  10328.685      10314.91       10321.135      10308.12
#  10307.955      10329.585      10344.86       10371.14
#  10339.61       10343.84       10330.135      10308.29
#  10360.73       10362.58       10287.61       10348.77
#  10324.95       10367.18       10323.565       9843.695
#  10332.         10381.77       10336.54       10330.135
#  10334.955      10335.955      10322.98       10340.405
#  10352.12       10381.415      10422.045      10391.855
#  10347.12       10331.885      10330.735      10365.9
#  10358.815      10340.84       10341.265      10390.255
#  10349.1        10334.175      10352.56       10338.015
#  10342.585      10352.885      10338.53       10352.855
#  10353.3        10413.955      10348.165      10332.375
#  10330.35       10356.155      10377.93       10338.265
#  10333.5        10350.915      10386.415      10304.19
#  10385.465      10333.11       10354.685      10355.445
#  10296.625      10333.995      10312.69       10332.56
#  10336.11       10383.145      10385.07       10433.31
#  10393.76       10342.735      10356.795      10392.45
#  10370.705      10347.555      10347.55       10332.505
#  10325.42       10409.975      10365.875      10355.255
#  10347.11       10341.405      10338.115      10316.085
#  10365.555      10349.38       10284.62       10275.985
#  10275.59       10344.08       10351.405      10261.3
#  10293.975      10339.36       10292.11       10295.75
#  10259.685      10322.195      10254.855      10274.105
#  10341.22       10276.6        10219.17       10308.36
#  10188.355      10214.87       10172.615      10224.125
#  10220.61       10244.72       10241.32       10204.07
#  10194.905      10177.615      10193.07       10211.26
#  10240.21       10187.825      10133.135      10166.415
#  10152.675      10176.495      10136.175      10119.12
#  10193.78       10134.72       10160.515      10096.975
#  10109.45       10134.735      10103.86       10155.325
#  10044.2        10134.43       10105.755      10054.33
#  10141.025      10027.52       10095.805      10061.74
#  10066.175      10065.29       10056.83       10079.105
#  10065.335      10085.77       10052.135      10101.21
#  10046.235      10062.905      10079.45       10077.1
#  10052.335      10010.635      10066.175      10090.53
#  10069.435      10053.32       10103.38       10042.415
#  10053.51       10045.815      10084.3        10082.635
#  10025.42       10042.025      10083.9        10028.28
#  10051.89       10067.405      10106.695      10045.35
#  10060.89       10022.385      10047.095      10038.21
#  10078.85       10040.165      10070.48       10052.275
#  10007.01       10047.49       10061.215      10072.845
#   9990.45       10044.89        9934.245      10008.085
#  10007.715      10019.22       10018.19        9967.35
#  10021.34        9958.43       10023.43       10027.495
#   9989.08       10022.59        9952.445       9983.97
#  10021.675      10005.4        10005.87        9999.78
#   9964.97       10019.985       9982.86        9987.305
#  10016.085       9988.795      10005.          9959.98
#   9970.275       9954.44        9979.21        9912.535
#   9900.485       9969.74        9949.765       9966.915
#   9907.835       9923.89        9987.63        9974.76
#   9939.895       9927.285       9933.56        9952.81
#   9911.355       9926.2         9961.08        9924.42
#   9873.94        9867.82        9905.5         9930.205
#   9942.3         9889.45        9916.76        9934.13
#   9895.385       9848.565       9877.785       9880.175
#   9879.625       9914.91        9922.          9852.41
#   9896.685       9858.87        9890.19        9905.55
#   9964.125       9933.18        9900.68        9952.175
#   9904.995       9924.37        9936.055       9848.695
#   9896.065       9890.56        9887.59        9910.76
#   9876.06        9929.31        9874.36        9895.33
#   9836.64        9902.13        9832.67        9939.935
#   9863.37        9933.525       9901.73        9945.785
#  10001.865       9888.31        9980.12        9925.38
#   9862.26        9980.06        9919.805      10011.045
#   9984.115       9928.905       9957.025       9975.66
#  10008.225       9998.89       10022.76        9978.555
#  10010.045      10008.28       10035.68       10058.555
#  10004.72       10016.395      10041.305      10098.73
#  10063.76       10067.815      10093.605      10053.915
#  10089.68       10083.49       10075.875      10097.565
#  10164.505      10071.09       10072.         10190.75
#  10072.12       10139.33       10056.13       10001.58
#   9983.966      10034.42        9971.178      10089.99
#  10019.8        10074.06       10044.81       10006.91
#   9948.564      10003.39        9823.428      10014.9
#  10087.22        9960.155       9877.512      10025.06
#  10019.5         9935.744      10001.98        9935.115
#   9992.824       9896.712       9987.87       10060.25
#   9918.983       9971.405       9941.196      10051.65
#  10116.43        9889.766       9944.179       9971.52
#   9991.212       9945.13        9937.558       9874.318
#   9973.326      10059.18        9973.728      10052.4
#   9942.332       9978.572      10102.71        9999.122
#   9981.954       9976.136       9942.759       9951.588
#   9934.298      10089.47       10015.62       10000.72
#  10036.11       10000.24       10016.07        9958.197
#   9943.996       9922.833       9971.695       9963.106
#  10038.35        9977.252      10045.23        9996.158
#  10009.03        9953.633       9898.417       9942.538
#   9997.757      10013.51        9861.326      10027.44
#  10011.04        9949.06       10004.11       10016.54
#   9876.753       9970.047      10018.14        9960.413
#   9988.138       9898.524      10121.59       10019.97
#   9915.945       9918.08        9942.44       10014.94
#  10095.24        9863.725      10069.58        9934.938
#  10046.75        9926.909       9863.743       9979.547
#   9945.859       9948.089       9924.907      10044.21
#   9920.211       9940.706       9897.678       9902.426
#  10012.35        9988.455       9952.476       9841.259
#   9891.96666667  9966.66666667  9969.29166667  9940.71666667
#   9918.38333333  9950.56666667  9966.73333333 10010.5
#   9995.78333333  9845.09166667  9935.05        9898.15
#   9966.79166667 10013.90833333  9960.35833333  9978.2
#   9956.86666667  9995.31666667 10032.43333333  9931.9
#   9948.98333333  9882.86666667  9967.89166667  9949.00833333
#  10002.46666667  9915.36666667  9927.25833333  9925.64166667
#   9936.575       9883.975       9859.54166667  9887.975
#   9932.73333333  9885.79166667  9910.975       9896.59166667
#   9852.58333333 10022.05        9882.11666667  9960.125
#   9830.24166667  9929.05        9957.6         9947.63333333
#   9892.575       9919.04166667  9894.60833333  9856.21666667
#   9984.31666667  9856.84166667  9850.53333333  9938.33333333
#   9821.68333333  9870.20833333  9838.86666667  9832.6
#   9848.          9890.53333333  9651.63333333  9771.04166667
#   9874.50833333  9879.59166667  9701.95        9652.28333333
#   9793.08333333  9739.19166667  9767.325       9771.05
#   9698.59166667  9814.21666667  9733.15        9870.73333333
#   9756.98333333  9717.74166667  9798.04166667  9700.93333333
#   9772.35        9764.625       9814.85        9844.98333333
#   9709.125       9921.4         9781.525       9680.175
#   9723.775       9721.275       9715.8         9783.575
#   9826.8         9765.75        9888.95833333  9754.375
#   9784.025       9942.35833333  9724.125       9752.69166667
#   9791.06666667  9717.80833333  9773.975       9882.75
#   9768.68333333  9761.1         9714.45        9712.18333333
#   9825.36666667  9789.98333333  9812.775       9896.64166667
#   9715.          9752.05833333  9689.91666667  9798.15833333
#   9807.175       9749.59166667  9782.05        9755.78333333
#   9724.5         9667.15833333  9747.79166667  9703.45833333
#   9784.425       9632.41666667  9812.84166667  9726.83333333
#   9682.65833333  9709.50833333  9651.775       9730.98333333
#   9701.          9645.725       9593.91666667  9763.775
#   9691.50833333  9736.01666667  9725.25833333  9676.49166667
#   9732.84166667  9670.31666667  9620.43333333  9714.08333333
#   9554.04166667  9781.825       9690.6         9688.05
#   9642.01666667  9702.2         9706.28333333  9638.79166667
#   9741.06666667  9642.65833333  9751.71666667  9732.38333333
#   9654.75833333  9649.44166667  9675.65      ]
# [3.7058655  3.5989195  3.6219755  3.5977125  3.601891   3.6059575
#  3.596031   3.607301   3.6029015  3.6100115  3.612684   3.614542
#  3.60683    3.600769   3.6079375  3.597473   3.604877   3.5996375
#  3.595478   3.6172675  3.6239885  3.626996   3.6353445  3.6354415
#  3.62995    3.614317   3.623416   3.637789   3.627191   3.6130555
#  3.6175725  3.6098445  3.6094905  3.619375   3.6071485  3.604907
#  3.620946   3.716672   3.6378235  3.616705   3.610143   3.6231815
#  3.6274515  3.616359   3.6098765  3.6017305  3.5941895  3.599785
#  3.603016   3.602516   3.60249    3.596585   3.601719   3.609968
#  3.599875   3.5973835  3.6119175  3.610322   3.6144635  3.606429
#  3.612081   3.604904   3.608823   3.6146845  3.611731   3.6006295
#  3.5937965  3.6107325  3.6025     3.6086945  3.61715    3.619941
#  3.6101585  3.619949   3.620968   3.6187935  3.6033655  3.6152445
#  3.6166965  3.6038355  3.605158   3.593207   3.612787   3.614307
#  3.6064415  3.613955   3.618961   3.6198995  3.6071685  3.6217115
#  3.6182795  3.6013125  3.615544   3.6109205  3.607318   3.6161455
#  3.606466   3.621336   3.6153585  3.61989    3.619946   3.611457
#  3.618821   3.6155295  3.6286955  3.609292   3.61129    3.6222645
#  3.610716   3.6038475  3.623864   3.6122755  3.621332   3.622077
#  3.6113085  3.610222   3.6149325  3.624617   3.61204    3.6243815
#  3.6186095  3.6153265  3.6235045  3.609417   3.6184185  3.61565
#  3.6149335  3.6381205  3.6080195  3.6313435  3.6213205  3.618696
#  3.621302   3.6061895  3.6224235  3.6191575  3.632087   3.6227935
#  3.6210575  3.624393   3.6241275  3.6183875  3.6222375  3.6252245
#  3.617417   3.612353   3.6305715  3.612472   3.629374   3.608143
#  3.61721    3.633981   3.617054   3.6177225  3.6174715  3.613023
#  3.617618   3.6202155  3.6367095  3.627012   3.623834   3.612782
#  3.621833   3.615856   3.603836   3.601507   3.6211305  3.611326
#  3.616547   3.6127435  3.620432   3.604847   3.6028395  3.611017
#  3.617412   3.6211075  3.610977   3.6231275  3.614776   3.633268
#  3.625297   3.6154265  3.617355   3.6245985  3.612423   3.6317115
#  3.6295285  3.6286095  3.6111905  3.6109075  3.6106205  3.6220665
#  3.613743   3.630943   3.627017   3.622238   3.6206975  3.6142515
#  3.6103615  3.615362   3.623666   3.6129515  3.610175   3.6373335
#  3.6091505  3.606102   3.621929   3.624999   3.621525   3.6327385
#  3.6299855  3.6265995  3.6259155  3.6177505  3.630145   3.62232
#  3.6257495  3.646507   3.637625   3.6173335  3.6279665  3.612769
#  3.62213    3.6220685  3.6276015  3.6196275  3.615969   3.628812
#  3.6275735  3.6205985  3.6251075  3.6239035  3.624639   3.6332165
#  3.6217165  3.625938   3.631742   3.620082   3.6419535  3.6273345
#  3.6311505  3.632601   3.6196245  3.6169375  3.6155905  3.6155245
#  3.633721   3.6403655  3.638645   3.6230435  3.625902   3.6290105
#  3.6242905  3.621657   3.6407645  3.6189585  3.627939   3.6108355
#  3.6274285  3.645284   3.62482    3.6280845  3.6168835  3.6228185
#  3.628852   3.634181   3.6256125  3.6400285  3.617214   3.6351205
#  3.6207375  3.629562   3.6237265  3.6229395  3.6326365  3.624208
#  3.6237975  3.611509   3.6150945  3.6240635  3.6170245  3.622399
#  3.6133585  3.620817   3.605062   3.6280135  3.6227835  3.6248295
#  3.624035   3.6204435  3.6279085  3.641845   3.6324855  3.625632
#  3.623254   3.631064   3.619914   3.625762   3.626352   3.615455
#  3.62572    3.6246085  3.6185635  3.6192245  3.6313515  3.613884
#  3.628196   3.6301635  3.624221   3.621846   3.623604   3.6373945
#  3.6463855  3.6296385  3.6146795  3.624835   3.6411905  3.66144
#  3.6245545  3.631771   3.63279    3.643149   3.6316405  3.6352155
#  3.6344745  3.6468655  3.6284625  3.6230365  3.63669    3.6302845
#  3.632431   3.6306885  3.647555   6.931503   6.952047   6.921304
#  6.949235   6.953336   6.917261   6.929316   6.935024   6.936298
#  6.932053   6.943998   6.945084   6.92855    6.942146   6.947595
#  6.925603   6.938028   6.936179   6.951221   6.954574   6.951234
#  6.953441   6.94134    6.943557   6.943803   6.935184   6.951924
#  6.927193   6.93226    6.950683   6.929273   6.924889   6.933541
#  6.936169   6.917203   6.955798   6.931925   6.943975   6.948241
#  6.951156   6.92282    6.936967   6.933623   6.909026   6.93665
#  6.923792   6.961703   6.94632    6.933365   6.921514   6.934594
#  6.929698   6.945884   6.923331   6.962054   6.965163   6.932818
#  6.961817   6.963657   6.926862   6.945305   6.926537   6.934504
#  6.957842   6.914602   6.933339   6.943433   6.976399   6.929768
#  6.945766   6.944521   6.934413   6.937074   6.936439   6.962514
#  6.93158    6.954709   6.931136   6.91882    6.937156   6.958389
#  6.952146   6.919363   6.939657   6.936957   6.956057   6.943521
#  6.939911   6.925707   6.915455   6.971766   6.949876   6.940495
#  6.94031    6.936595   6.928529   6.955027   6.960309   6.953648
#  6.935045   6.942642   6.947734   6.950343   6.955917   6.948405
#  6.940424   6.935107   6.936021   6.957333   6.937563   6.948605
#  6.948595   6.93168    6.971585   6.972102   5.83942417 5.82914833
#  5.82541167 5.84325167 5.828035   5.83048    5.83026667 5.83596333
#  5.85111917 5.82432833 5.82848    5.82481833 5.82503833 5.81864333
#  5.83141167 5.83000417 5.832215   5.84784917 5.83919417 5.83522333
#  5.82605833 5.83234583 5.8116275  5.8478575  5.83563583 5.8077875
#  5.84643833 5.83695583 5.83314417 5.82235917 5.84113    5.83001
#  5.82564083 5.8373875  5.84954417 5.82247167 5.8285475  5.8490125
#  5.84657833 5.80770083 5.843935   5.83525083 5.83290333 5.84165083
#  5.84251833 5.8805     5.849805   5.84865417 5.83639333 5.85449833
#  5.854035   5.8388675  5.85372    5.83258917 5.85027667 5.84761833
#  5.84823    5.84936083 5.82926333 5.84666583 5.81952083 5.83302333
#  5.87048667 5.85126333 5.845925   5.84117917 5.847095   5.86000667
#  5.8368025  5.8431475  5.8376925  5.83792583 5.86131833 5.84690833
#  5.839905   5.8554475  5.822555   5.838845   5.83229583 5.83789583
#  5.82704083 5.855995   5.86393    5.85740417 5.85020417 5.86037417
#  5.84797833 5.86662833 5.85259333 5.86379333 5.8509025  5.8377475
#  5.82818583 5.85132583 5.84955083 5.8657725  5.85732    5.85050167
#  5.88611333 5.84845917 5.8502     5.84119583 5.86456583 5.845305
#  5.84585667 5.8626775  5.85528333 5.87381583 5.86162    5.86732583
#  5.85716    5.84941083 5.85103917 5.8595425  5.8496     5.84922833
#  5.86132    5.8611125  5.86105    5.8313525  5.87649417 5.85896333
#  5.8543475  5.84888167 5.85090167 5.8604125  5.84953583 5.85683417
#  5.85094    5.8567375  5.86166083 5.84770083 5.84405667 5.85515
#  5.83872833 5.86631417 5.86090833 5.85687167 5.86431417 5.85956917
#  5.88490167 5.85069167 5.85631333 5.83453167 5.862055   5.8638525
#  5.8567775  5.85030583 5.86426583 5.84265583 5.85879833 5.86729917
#  5.88502583 5.87043917 5.86476917]

# %% [markdown]
# Next, we normalize the flux and flux error by the flux averages.

# %%
# Reference 1 star flux error
ref1_flux_err = df_ref1_flux['Flux error'].to_numpy()
ref1_flux_err = ref1_flux_err.astype(float)

# Normalize flux and flux error
ref1_flux_norm = ref1_flux/ref1_mean_flux
ref1_flux_err_norm = ref1_flux_err/ref1_mean_flux

# Reference 2 star
ref2_flux_err = df_ref2_flux['Flux error'].to_numpy()
ref2_flux_err = ref2_flux_err.astype(float)

ref2_flux_norm = ref2_flux/ref2_mean_flux
ref2_flux_err_norm = ref2_flux_err/ref2_mean_flux

# Reference 3 star
ref3_flux_err = df_ref3_flux['Flux error'].to_numpy()
ref3_flux_err = ref3_flux_err.astype(float)

ref3_flux_norm = ref3_flux/ref3_mean_flux
ref3_flux_err_norm = ref3_flux_err/ref3_mean_flux

# Reference 4 star
ref4_flux_err = df_ref4_flux['Flux error'].to_numpy()
ref4_flux_err = ref4_flux_err.astype(float)

ref4_flux_norm = ref4_flux/ref4_mean_flux
ref4_flux_err_norm = ref4_flux_err/ref4_mean_flux

# Reference 5 star
ref5_flux_err = df_ref5_flux['Flux error'].to_numpy()
ref5_flux_err = ref5_flux_err.astype(float)

ref5_flux_norm = ref5_flux/ref5_mean_flux
ref5_flux_err_norm = ref5_flux_err/ref5_mean_flux

# Reference 6 star
ref6_flux_err = df_ref6_flux['Flux error'].to_numpy()
ref6_flux_err = ref6_flux_err.astype(float)

ref6_flux_norm = ref6_flux/ref6_mean_flux
ref6_flux_err_norm = ref6_flux_err/ref6_mean_flux

# Reference 7 star
ref7_flux_err = df_ref7_flux['Flux error'].to_numpy()
ref7_flux_err = ref7_flux_err.astype(float)

ref7_flux_norm = ref7_flux/ref7_mean_flux
ref7_flux_err_norm = ref7_flux_err/ref7_mean_flux

# Reference 8 star
ref8_flux_err = df_ref8_flux['Flux error'].to_numpy()
ref8_flux_err = ref8_flux_err.astype(float)

ref8_flux_norm = ref8_flux/ref8_mean_flux
ref8_flux_err_norm = ref8_flux_err/ref8_mean_flux

# Reference 9 star
ref9_flux_err = df_ref9_flux['Flux error'].to_numpy()
ref9_flux_err = ref9_flux_err.astype(float)

ref9_flux_norm = ref9_flux/ref9_mean_flux
ref9_flux_err_norm = ref9_flux_err/ref9_mean_flux

# Reference 10 star
ref10_flux_err = df_ref10_flux['Flux error'].to_numpy()
ref10_flux_err = ref10_flux_err.astype(float)

ref10_flux_norm = ref10_flux/ref10_mean_flux
ref10_flux_err_norm = ref10_flux_err/ref10_mean_flux

# Science star
sci_flux_err = df_sci_flux['Flux error'].to_numpy()
sci_flux_err = sci_flux_err.astype(float)

sci_flux_norm = sci_flux/sci_mean_flux
sci_flux_err_norm = sci_flux_err/sci_mean_flux

# %% [markdown]
# Next, we extract the observation times. All reference stars have the same observation times, so we can just extract times from 1 of them.

# %%
# Reference star observing times (numpy array of strings)
ref_times = df_ref1_flux['Obs time'].to_numpy()
print(type(ref_times[0]))
# Out:
# <class 'numpy.datetime64'>

# %% [markdown]
# We check if the list of observing times is strictly increasing, using a code sample taken from https://www.geeksforgeeks.org/python-check-if-list-is-strictly-increasing/

# %%
# Check if list of times is strictly increasing

# using zip() + all()
# to check for strictly increasing list
res = all(i < j for i, j in zip(ref_times, ref_times[1:]))
 
# printing result
print ("Is list strictly increasing ? : " + str(res))
# Out:
# Is list strictly increasing ? : True

# %% [markdown]
# Generate lightcurve plots

# %%
plt.errorbar(ref_times, ref1_flux_norm, yerr=ref1_flux_err_norm, fmt='.', label='Star 1')
plt.errorbar(ref_times, ref2_flux_norm+0.1, yerr=ref2_flux_err_norm, fmt='.', label='Star 2')
plt.errorbar(ref_times, ref3_flux_norm+0.2, yerr=ref3_flux_err_norm, fmt='.', label='Star 3')
plt.errorbar(ref_times, ref4_flux_norm+0.3, yerr=ref4_flux_err_norm, fmt='.', label='Star 4')
plt.errorbar(ref_times, ref5_flux_norm+0.4, yerr=ref5_flux_err_norm, fmt='.', label='Star 5')
plt.errorbar(ref_times, ref6_flux_norm+0.5, yerr=ref6_flux_err_norm, fmt='.', label='Star 6')
plt.errorbar(ref_times, ref7_flux_norm+0.6, yerr=ref7_flux_err_norm, fmt='.', label='Star 7')
plt.errorbar(ref_times, ref8_flux_norm+0.7, yerr=ref8_flux_err_norm, fmt='.', label='Star 8')
plt.errorbar(ref_times, ref9_flux_norm+0.8, yerr=ref9_flux_err_norm, fmt='.', label='Star 9')
plt.errorbar(ref_times, ref10_flux_norm+0.9, yerr=ref10_flux_err_norm, fmt='.', label='Star 10')
plt.errorbar(ref_times, sci_flux_norm+1.0, yerr=sci_flux_err_norm, fmt='.', label='Science Star')

#plt.legend(loc='best')
plt.xlabel('Time of observation')
# plt.ylabel('Relative flux')
plt.title('Lightcurves')

# Save plot to the Analysis directory
os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/Analysis')
plt.savefig('reference_star_lightcurves.png')

# %% [markdown]
# We remove stars 1, 4, 5, and 10 since they display excessive variation.
#
# We want to remove the outlier points we see in the lightcurves. There are 2 exposures that appear to be outliers (at times 79000 and 80500). We can remove these outliers by plotting observations after time 81000.

# %% [markdown]
# 4.5 - Calibration of the Science Target Photometry

# %% [markdown]
# Missing .cat files: 000000333, 00000334, 00000339, 00000451.

# %%
for i in range(607):
    if i < 10:
        name = 'science.0000' + '000' + str(i) + '.FIT'
    elif i < 100:
        name = 'science.0000' + '00' + str(i) + '.FIT'
    else:
        name = 'science.0000' + '0' + str(i) + '.FIT'
    
    os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/RAW')
    if not os.path.exists(name):
        continue # print(name,' not found.')
        
print('TEST FOR CALIBRATION EXISTENCE.')
        
for j in range(607):
    if j < 10:
        calname = 'calibscience.0000' + '000' + str(j) + '.fits.cat'
    elif j < 100:
        calname = 'calibscience.0000' + '00' + str(j) + '.fits.cat'
    else:
        calname = 'calibscience.0000' + '0' + str(j) + '.fits.cat'
    
    os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/SCIENCE!/Calib20s')
    if not os.path.exists(calname):
        continue # print(calname,' not found.')

# Conclusions: 0 - 332 is 20 seconds. 452 - 606 is 12 seconds. 335 - 338, 340 - 450 is 10 seconds.
# Raw files 333, 451 not found. As of 20:08 September 25th, 2022, 334 and 339 have been deleted.
# Calibration files 333, 334, 339, and 451 not found.
# Therefore, exclude 333, 334, 339, and 451 from analyses.
# Out:
# TEST FOR CALIBRATION EXISTENCE.

# %%
# Sanity checks.

print(df_ref1) # 603 elements, missing four. See above cell.
print(df_ref2)
print(df_ref3)
print(df_ref4)
print(df_ref5)
print(df_ref6)
print(df_ref7)
print(df_ref8)
print(df_ref9)
print(df_ref10)

# Essentially, in each flux table, the 334th row is for image 00000335, 335th is 00000336, and so forth. Use this to skip appropriate reference times.
# Out:
#     Index          RA        Dec                Obs time        Flux  \
# 0       0  300.200646  22.803276 2022-08-31 21:58:19.433     587.881
# 1       1  300.200625  22.803301 2022-08-31 21:59:08.873   474.62245
# 2       2  300.200638  22.803289 2022-08-31 22:04:45.616    459.8126
# 3       3  300.200647  22.803281 2022-08-31 22:05:10.579    469.8772
# 4       4  300.200639  22.803287 2022-08-31 22:05:36.205    464.8231
# ..    ...         ...        ...                     ...         ...
# 598   602  300.200598  22.803294 2022-09-01 01:58:10.529   446.36975
# 599   603  300.200618  22.803272 2022-09-01 01:58:27.817  437.183917
# 600   604  300.200637  22.803288 2022-09-01 01:58:44.935   448.27975
# 601   605  300.200612  22.803259 2022-09-01 01:59:02.089     453.452
# 602   606  300.200647  22.803281 2022-09-01 01:59:19.441  450.221083
#
#     Flux error
# 0      3.71625
# 1     3.595255
# 2     3.623821
# 3     3.604125
# 4     3.601891
# ..         ...
# 598    5.85432
# 599   5.870292
# 600   5.883527
# 601   5.861497
# 602   5.866263
#
# [603 rows x 6 columns]
#     Index          RA        Dec                Obs time         Flux  \
# 0       0  300.237463  22.846977 2022-08-31 21:58:19.433      9244.54
# 1       1  300.237431  22.847006 2022-08-31 21:59:08.873     7407.105
# 2       2  300.237439  22.846977 2022-08-31 22:04:45.616     7366.895
# 3       3  300.237452  22.846979 2022-08-31 22:05:10.579     7407.355
# 4       4  300.237437  22.846966 2022-08-31 22:05:36.205     7377.705
# ..    ...         ...        ...                     ...          ...
# 598   602  300.237419  22.846961 2022-09-01 01:58:10.529  7004.303333
# 599   603  300.237412  22.846982 2022-09-01 01:58:27.817  7012.311667
# 600   604  300.237427  22.846971 2022-09-01 01:58:44.935  6964.858333
# 601   605  300.237411  22.846985 2022-09-01 01:59:02.089  6948.391667
# 602   606  300.237415  22.846976 2022-09-01 01:59:19.441  7041.213333
#
#     Flux error
# 0     3.710589
# 1     3.597088
# 2     3.623821
# 3     3.599546
# 4      3.60648
# ..         ...
# 598   5.861782
# 599   5.870292
# 600   5.894012
# 601   5.861497
# 602   5.864769
#
# [603 rows x 6 columns]
#     Index          RA        Dec                Obs time         Flux  \
# 0       0  300.026073  22.704524 2022-08-31 21:58:19.433     3342.118
# 1       1  300.026001  22.704574 2022-08-31 21:59:08.873     2657.169
# 2       2  300.025984  22.704609 2022-08-31 22:04:45.616     2664.983
# 3       3  300.025992  22.704549 2022-08-31 22:05:10.579     2672.483
# 4       4  300.026014   22.70458 2022-08-31 22:05:36.205     2688.773
# ..    ...         ...        ...                     ...          ...
# 598   602  300.025986  22.704605 2022-09-01 01:58:10.529  2563.130833
# 599   603  300.025993  22.704594 2022-09-01 01:58:27.817      2531.79
# 600   604  300.025996  22.704588 2022-09-01 01:58:44.935  2558.805833
# 601   605  300.026017  22.704594 2022-09-01 01:59:02.089  2533.371667
# 602   606  300.026023  22.704597 2022-09-01 01:59:19.441    2562.1675
#
#     Flux error
# 0     3.705866
# 1     3.598004
# 2     3.625666
# 3     3.597713
# 4      3.60648
# ..         ...
# 598   5.855812
# 599   5.874778
# 600   5.894012
# 601    5.86895
# 602   5.857295
#
# [603 rows x 6 columns]
#     Index          RA        Dec                Obs time        Flux  \
# 0       0   300.13484  22.879741 2022-08-31 21:58:19.433     718.649
# 1       1  300.134761  22.879822 2022-08-31 21:59:08.873     568.307
# 2       2  300.134775  22.879833 2022-08-31 22:04:45.616     566.139
# 3       3   300.13476  22.879795 2022-08-31 22:05:10.579     573.453
# 4       4   300.13476  22.879812 2022-08-31 22:05:36.205    561.1935
# ..    ...         ...        ...                     ...         ...
# 598   602  300.134719  22.879809 2022-09-01 01:58:10.529  557.451167
# 599   603  300.134759  22.879822 2022-09-01 01:58:27.817  539.414833
# 600   604  300.134685  22.879838 2022-09-01 01:58:44.935  556.381917
# 601   605  300.134726   22.87987 2022-09-01 01:59:02.089  545.078583
# 602   606  300.134751  22.879827 2022-09-01 01:59:19.441  550.352333
#
#     Flux error
# 0     3.712477
# 1     3.599835
# 2     3.622898
# 3     3.607784
# 4      3.60281
# ..         ...
# 598   5.852826
# 599   5.874778
# 600   5.873022
# 601    5.86448
# 602   5.857295
#
# [603 rows x 6 columns]
#     Index          RA        Dec                Obs time        Flux  \
# 0       0  300.097929   22.65066 2022-08-31 21:58:19.433     576.676
# 1       1  300.097894  22.650668 2022-08-31 21:59:08.873   465.19935
# 2       2  300.097887   22.65072 2022-08-31 22:04:45.616    450.7184
# 3       3  300.097884  22.650668 2022-08-31 22:05:10.579   456.98765
# 4       4  300.097912  22.650696 2022-08-31 22:05:36.205    461.7873
# ..    ...         ...        ...                     ...         ...
# 598   602  300.097905  22.650712 2022-09-01 01:58:10.529     436.225
# 599   603  300.097911  22.650695 2022-09-01 01:58:27.817   441.77875
# 600   604  300.097866  22.650725 2022-09-01 01:58:44.935  422.114083
# 601   605  300.097888  22.650687 2022-09-01 01:59:02.089  427.865083
# 602   606   300.09789  22.650704 2022-09-01 01:59:19.441  425.820917
#
#     Flux error
# 0     3.705866
# 1     3.597088
# 2     3.622898
# 3     3.596796
# 4     3.600054
# ..         ...
# 598   5.861782
# 599    5.87926
# 600   5.883527
# 601    5.86597
# 602   5.861781
#
# [603 rows x 6 columns]
#     Index          RA        Dec                Obs time         Flux  \
# 0       0  300.177708  22.574765 2022-08-31 21:58:19.433     1881.342
# 1       1  300.177746  22.574734 2022-08-31 21:59:08.873     1477.824
# 2       2  300.177741  22.574753 2022-08-31 22:04:45.616     1498.427
# 3       3  300.177739  22.574767 2022-08-31 22:05:10.579     1490.636
# 4       4  300.177741  22.574747 2022-08-31 22:05:36.205     1497.136
# ..    ...         ...        ...                     ...          ...
# 598   602  300.177729  22.574772 2022-09-01 01:58:10.529      1385.78
# 599   603  300.177703   22.57477 2022-09-01 01:58:27.817      1414.66
# 600   604  300.177726  22.574749 2022-09-01 01:58:44.935     1382.225
# 601   605  300.177719  22.574758 2022-09-01 01:59:02.089  1390.849167
# 602   606  300.177696  22.574785 2022-09-01 01:59:19.441      1395.22
#
#     Flux error
# 0     3.713421
# 1      3.59892
# 2     3.621976
# 3     3.603209
# 4      3.60281
# ..         ...
# 598   5.864764
# 599   5.870292
# 600   5.885026
# 601   5.857022
# 602   5.866263
#
# [603 rows x 6 columns]
#     Index          RA        Dec                Obs time         Flux  \
# 0       0  300.048948  22.712918 2022-08-31 21:58:19.433     1956.961
# 1       1  300.048866  22.712973 2022-08-31 21:59:08.873     1581.981
# 2       2  300.048852  22.712997 2022-08-31 22:04:45.616    1578.7535
# 3       3  300.048878  22.712941 2022-08-31 22:05:10.579    1586.1985
# 4       4   300.04888  22.712979 2022-08-31 22:05:36.205     1580.731
# ..    ...         ...        ...                     ...          ...
# 598   602  300.048858  22.712999 2022-09-01 01:58:10.529  1486.759167
# 599   603  300.048862  22.712973 2022-09-01 01:58:27.817  1514.871667
# 600   604  300.048871  22.712991 2022-09-01 01:58:44.935  1483.535833
# 601   605  300.048868  22.712965 2022-09-01 01:59:02.089    1478.1775
# 602   606  300.048893  22.712989 2022-09-01 01:59:19.441  1484.968333
#
#     Flux error
# 0       3.7087
# 1      3.59892
# 2     3.623821
# 3     3.599546
# 4     3.604645
# ..         ...
# 598   5.866255
# 599   5.876272
# 600   5.882027
# 601    5.86746
# 602   5.861781
#
# [603 rows x 6 columns]
#     Index          RA        Dec                Obs time        Flux  \
# 0       0  300.294404  22.832853 2022-08-31 21:58:19.433     779.763
# 1       1  300.294402   22.83287 2022-08-31 21:59:08.873    619.5635
# 2       2  300.294431  22.832821 2022-08-31 22:04:45.616     624.766
# 3       3  300.294398  22.832823 2022-08-31 22:05:10.579    626.2335
# 4       4  300.294406  22.832823 2022-08-31 22:05:36.205    624.6605
# ..    ...         ...        ...                     ...         ...
# 598   602  300.294381  22.832824 2022-09-01 01:58:10.529   595.14925
# 599   603  300.294369  22.832836 2022-09-01 01:58:27.817  592.607167
# 600   604  300.294386  22.832828 2022-09-01 01:58:44.935   588.72875
# 601   605   300.29438  22.832802 2022-09-01 01:59:02.089  599.380167
# 602   606  300.294368  22.832814 2022-09-01 01:59:19.441   588.60075
#
#     Flux error
# 0     3.703974
# 1     3.606238
# 2     3.620128
# 3     3.598629
# 4     3.604645
# ..         ...
# 598   5.857306
# 599    5.87926
# 600   5.883527
# 601   5.861497
# 602   5.863275
#
# [603 rows x 6 columns]
#     Index          RA        Dec                Obs time        Flux  \
# 0       0  300.245241  22.685155 2022-08-31 21:58:19.433    1162.044
# 1       1  300.245265  22.685132 2022-08-31 21:59:08.873     921.433
# 2       2  300.245277  22.685127 2022-08-31 22:04:45.616    928.3105
# 3       3  300.245276  22.685134 2022-08-31 22:05:10.579     925.666
# 4       4  300.245266  22.685151 2022-08-31 22:05:36.205    932.5665
# ..    ...         ...        ...                     ...         ...
# 598   602  300.245223  22.685158 2022-09-01 01:58:10.529    870.4525
# 599   603  300.245226   22.68515 2022-09-01 01:58:27.817  873.811667
# 600   604  300.245245  22.685149 2022-09-01 01:58:44.935  860.491667
# 601   605  300.245273  22.685119 2022-09-01 01:59:02.089  871.523333
# 602   606  300.245187  22.685113 2022-09-01 01:59:19.441  878.624167
#
#     Flux error
# 0       3.7087
# 1     3.598004
# 2     3.622898
# 3     3.596796
# 4     3.604645
# ..         ...
# 598   5.860291
# 599   5.864304
# 600   5.882027
# 601   5.857022
# 602   5.857295
#
# [603 rows x 6 columns]
#     Index          RA        Dec                Obs time        Flux  \
# 0       0   300.12249  22.572338 2022-08-31 21:58:19.433    483.5359
# 1       1  300.122507  22.572318 2022-08-31 21:59:08.873     381.806
# 2       2  300.122522  22.572336 2022-08-31 22:04:45.616   371.95845
# 3       3  300.122498  22.572319 2022-08-31 22:05:10.579     383.308
# 4       4  300.122515  22.572351 2022-08-31 22:05:36.205   386.71315
# ..    ...         ...        ...                     ...         ...
# 598   602  300.122479  22.572367 2022-09-01 01:58:10.529  344.783417
# 599   603  300.122475  22.572351 2022-09-01 01:58:27.817   353.11325
# 600   604    300.1225  22.572317 2022-09-01 01:58:44.935  350.915917
# 601   605  300.122518  22.572326 2022-09-01 01:59:02.089  349.147083
# 602   606  300.122502  22.572343 2022-09-01 01:59:19.441  349.088583
#
#     Flux error
# 0       3.7087
# 1     3.597088
# 2     3.619205
# 3     3.597713
# 4     3.609231
# ..         ...
# 598   5.858798
# 599   5.874778
# 600   5.883527
# 601   5.852542
# 602   5.863275
#
# [603 rows x 6 columns]

# %%
print(df_sci)
# Out:
#     Index          RA        Dec                Obs time         Flux  \
# 0       0  300.182134  22.709241 2022-08-31 21:58:19.433    12844.825
# 1       1  300.182123   22.70925 2022-08-31 21:59:08.873     10276.45
# 2       2  300.182123  22.709261 2022-08-31 22:04:45.616    10251.225
# 3       3  300.182121  22.709243 2022-08-31 22:05:10.579     10317.68
# 4       4  300.182119   22.70926 2022-08-31 22:05:36.205    10302.055
# ..    ...         ...        ...                     ...          ...
# 598   602    300.1821   22.70925 2022-09-01 01:58:10.529  9751.716667
# 599   603  300.182093  22.709244 2022-09-01 01:58:27.817  9732.383333
# 600   604  300.182088  22.709257 2022-09-01 01:58:44.935  9654.758333
# 601   605  300.182108  22.709242 2022-09-01 01:59:02.089  9649.441667
# 602   606  300.182098  22.709234 2022-09-01 01:59:19.441      9675.65
#
#     Flux error
# 0     3.705866
# 1      3.59892
# 2     3.621976
# 3     3.597713
# 4     3.601891
# ..         ...
# 598   5.858798
# 599   5.867299
# 600   5.885026
# 601   5.870439
# 602   5.864769
#
# [603 rows x 6 columns]

# %%
print(ref_times[333]) # File number 333 is element 333 in ref_times.
print(ref_times[334]) # File number 334 is element 334 in ref_times.
print(ref_times[339]) # File number 339 is element 339 in ref_times.
print(ref_times[451]) # File number 451 is element 451 in ref_times.
# print(ref_times[606])

new_ref_times = []

for i in range(len(ref_times)):
    if i == 333 or i == 334 or i == 339 or i == 451:
        continue
    else:
        new_ref_times.append(ref_times[i])
# Out:
# 2022-09-01T00:28:01.265000000
# 2022-09-01T00:29:02.729000000
# 2022-09-01T00:46:12.212000000
# 2022-09-01T01:15:27.391000000

# %%
# Saity checks, and declaring a variable.

type(df_ref1)
#df_ref1.iloc[:,4] # Outputs the full flux column.
len(df_ref2.iloc[:,4]) # Outputs the length

#print(df_ref1.iloc[:,4][0]) # This outputs the first flux element for first reference star.

df_ref = [df_ref1,df_ref2,df_ref3,df_ref4,df_ref5,df_ref6,df_ref7,df_ref8,df_ref9,df_ref10]
# print(df_ref)

type(df_ref[1].iloc[:,4][100]) # Prints the 100th flux (5th column) entry for the 1st reference star.
# Out:
# numpy.float64

# %%
flux_mean_45 = []

for i in range(603): # Four lines missing. Corresponds to four missing files from the calibration directories? At most, offset by four frames.
    mean_numerator_45 = 0
    mean_denominator_45 = 0
    for j in range(10):
            mean_numerator_45 += float(df_ref[j].iloc[:,4][i])/(float(df_ref[j].iloc[:,5][i]))**2
            mean_denominator_45 += 1/float(df_ref[j].iloc[:,5][i])**2
    flux_mean_45.append(mean_numerator_45/mean_denominator_45)

# print(flux_mean_45) # Outputs an array with 603 entries, each entry represents the weighted mean flux over all reference stars.
print(len(flux_mean_45))

error_mean_45 = []

for i in range(603):
    error_auxiliary_var_45 = 0
    for j in range(10):
        error_auxiliary_var_45 += 1/float(df_ref[j].iloc[:,5][i])**2
    error_mean_45.append(np.sqrt(error_auxiliary_var_45))
            
# print(error_mean_45) # Outputs an array with 603 entries, each entry represents the error in mean flux over all reference stars.
print(len(error_mean_45))
# Out:
# 603
# 603

# %%
print(flux_mean_45)
print(error_mean_45)
# Out:
# [2073.1829139320384, 1656.083943582544, 1650.2688903865187, 1659.6760305192865, 1656.6292156979484, 1658.7338815210403, 1657.063842321818, 1658.7297535709492, 1662.061162297809, 1663.7370754001427, 1665.3363380365554, 1666.4226954619655, 1663.6390014345916, 1664.274751687203, 1669.2853376299106, 1667.8096784393879, 1663.8739122694583, 1668.1022608689607, 1664.6111233339732, 1666.7506698401419, 1670.1655873647207, 1674.0435274369543, 1666.4491893554844, 1666.9193015196809, 1664.0463535392112, 1666.346309282856, 1663.7331543321723, 1669.3487722666212, 1669.7411169293127, 1661.9988406821012, 1664.479271547217, 1662.140309866704, 1665.938954200646, 1665.1776302613955, 1671.2533010690893, 1658.4410374894592, 1666.6586291749334, 1663.5483999517162, 1664.8584334612003, 1578.9118360937396, 1667.3140218744086, 1672.419322862783, 1670.298303908759, 1668.8462938469438, 1672.3554527089404, 1667.8828549618906, 1671.1259537956482, 1663.793805899763, 1664.8210755745947, 1667.6408009510908, 1668.5722876194561, 1670.5821647405742, 1670.5171784937736, 1667.145749641425, 1664.6595743611224, 1668.6468553057434, 1668.4799570864984, 1668.3399681634241, 1672.672517951217, 1670.5801082466737, 1669.7781056903027, 1668.060412981675, 1671.8633160699746, 1671.187201540339, 1668.264678516817, 1660.309052327395, 1667.8772202413752, 1665.4478010288908, 1661.4774089663151, 1670.776886302876, 1666.6471176946814, 1664.729861387679, 1670.3565648076594, 1665.7423797689928, 1673.0709879431909, 1659.6188456901384, 1664.5497945605675, 1669.2703207247705, 1673.688058122566, 1668.5450512489415, 1671.0412690947114, 1672.7136328816364, 1664.821447005827, 1667.0143013308054, 1664.269235616696, 1670.1925524992225, 1663.547563031675, 1675.1555462029762, 1667.62607600444, 1666.1586642412535, 1670.2701317428296, 1673.0162856594134, 1673.9891874181244, 1670.0309997652791, 1669.1154133917312, 1672.2056181454973, 1672.257972586079, 1676.548609766342, 1672.3179471754636, 1664.396941670173, 1665.1944543106952, 1672.6690245585623, 1670.2146268567817, 1673.689998815898, 1669.3033781707131, 1666.1156548760484, 1668.8550007150852, 1669.530186929198, 1664.383804278645, 1660.4596514345092, 1662.970695659963, 1663.6373434481025, 1668.1545895723693, 1665.055329431693, 1666.4669130835077, 1665.1293102900574, 1662.271222987786, 1666.0352377618506, 1668.446268847271, 1668.6498695593443, 1663.241138745047, 1668.2261337472576, 1667.9765078598493, 1664.0011716711317, 1665.5878430888579, 1664.736832874342, 1667.0228705003806, 1666.4318899587379, 1663.7852657297892, 1672.0466906822232, 1670.624873419658, 1674.1611492009658, 1666.2887467927121, 1671.2076576235563, 1671.8301152070774, 1667.4663777865737, 1665.114914957242, 1672.5317967880135, 1671.7954862097613, 1667.5774305639122, 1667.0116930142856, 1668.4057497193169, 1666.093358629059, 1667.2248148963386, 1667.5139475514738, 1674.2358196402117, 1665.8152537748003, 1666.674850249753, 1669.3622717205167, 1669.8531261507908, 1668.6991754266362, 1664.417108347611, 1666.4105851848226, 1670.1279435522902, 1667.1890267522233, 1665.129688702771, 1670.7245154660936, 1667.7413078778645, 1672.5543177936452, 1666.3515267450605, 1665.3904831586703, 1665.2512421451413, 1666.679605304138, 1668.762461928008, 1670.4371883857507, 1662.7024069317265, 1665.6427302130762, 1666.2223719455214, 1666.7404397252135, 1661.269757310276, 1672.0508214965955, 1666.7923464049354, 1663.5036021631975, 1669.91720647965, 1669.3866269457778, 1661.837955682078, 1659.8869655938613, 1663.0228723524026, 1668.4324652790556, 1668.9641716990775, 1659.8395649923111, 1668.9396371750663, 1668.8602927252819, 1665.3961924243192, 1662.6216017737256, 1673.6148699244152, 1660.107748216643, 1667.8964289585601, 1655.9520801366177, 1666.9948963353193, 1663.9744603570105, 1672.996567190511, 1657.189460160857, 1660.8983664963712, 1658.0426251778745, 1662.9636102183163, 1664.582202389382, 1661.6478268845851, 1656.7216669273598, 1661.5373086952982, 1659.4496304739694, 1662.6987215057231, 1661.0350255 ...
# [0.8524925213303965, 0.8787422666516612, 0.8729034531292101, 0.8783664522714204, 0.8773463366924995, 0.8764687175578627, 0.8795383963152351, 0.8781055206551363, 0.8780389296241989, 0.8772676649273867, 0.8745476899653344, 0.874498353584753, 0.8763473623615176, 0.8782015529028623, 0.8761902700858678, 0.8783801856606331, 0.8765981664617568, 0.8787007153272208, 0.8788679481721627, 0.8737289564990834, 0.8723081442756411, 0.8718732900747519, 0.8697601722901815, 0.8696256276505154, 0.8703002394536014, 0.8751763452214665, 0.8728680091217701, 0.8713896067396287, 0.8716059725901775, 0.8753283351792958, 0.8740118112210491, 0.8748777512071646, 0.8747413052245364, 0.8746646863776085, 0.8767158966300495, 0.8768581884347552, 0.8743991544916859, 0.8510120488095643, 0.8695230568315085, 0.8759342700723722, 0.8764790311493045, 0.8727690452559257, 0.8728072286950197, 0.8747278456987221, 0.8753824867704614, 0.877228171045269, 0.8784186334475987, 0.8784192061486819, 0.8771628945218336, 0.8783119283717877, 0.8773572466142509, 0.8779467868407257, 0.8765391560297755, 0.8757635820453122, 0.8798492908774631, 0.8789833221748801, 0.8755123359444287, 0.8756092377694974, 0.8743398489651043, 0.8785406909199837, 0.8757201074932411, 0.8775074891163676, 0.8755947741595024, 0.8751543088529072, 0.8746226461883736, 0.8778101727465288, 0.8803764846450097, 0.87557878015017, 0.8772659499803634, 0.8752458693685579, 0.8754244797596689, 0.8743072385290562, 0.8778554281651064, 0.8738595308167554, 0.8748799087277371, 0.873938115181673, 0.8757363979882207, 0.8761787987007553, 0.8742221789912153, 0.8773432862134883, 0.8765284662612522, 0.8788155601281283, 0.8751246077311844, 0.8744210918213692, 0.8776457942457355, 0.8745752509438318, 0.874099191370371, 0.8747627634937656, 0.8769573565322786, 0.872059007554676, 0.8746200447211697, 0.8778898075401658, 0.8742584569270268, 0.8753115765193727, 0.8758053989805935, 0.874289339500203, 0.8760775093394559, 0.8744132083929208, 0.8740104869045703, 0.8739866270129089, 0.8738835388814151, 0.8752221796967166, 0.8740210355366984, 0.875995129144146, 0.8719099459350498, 0.8754361943437761, 0.8748633446285644, 0.8732342083293053, 0.877342785883377, 0.87772035196073, 0.8735167063144175, 0.8758507452926528, 0.8731270369386888, 0.872213295055781, 0.875883627138804, 0.875723814100118, 0.8739806430470435, 0.872691330155594, 0.8749938770957879, 0.8720365299800508, 0.8736941985629612, 0.8750902349725495, 0.8736015975204532, 0.8760532437028046, 0.8725611851637953, 0.8739639530467302, 0.8726401081817852, 0.8715757312663576, 0.8760790604009676, 0.8719604773689851, 0.8733729983495501, 0.8735397891300567, 0.8734458602801386, 0.8751395329616237, 0.8729957489483243, 0.872405419862682, 0.8706316725826383, 0.8723069748435, 0.87468077367695, 0.8714324096030358, 0.8740749537703192, 0.8747271329859619, 0.8726183807655418, 0.8722100861111465, 0.8749611260089456, 0.8761659850874411, 0.8726325525108862, 0.8743097861941977, 0.8725438869490364, 0.8767413411313433, 0.8736976895888835, 0.8696010296111731, 0.8740909993797185, 0.8743983811326265, 0.8745689783675048, 0.8752457871504179, 0.874001713208441, 0.8735950412650498, 0.8712714650348627, 0.8716922364042289, 0.8733684753473826, 0.874411491819328, 0.8755368679162467, 0.8736691918042581, 0.8761570028777051, 0.8776436125884159, 0.8735093970655972, 0.8752556595703246, 0.8743934304971417, 0.8737534058890607, 0.8732102863734336, 0.8763809143661394, 0.8771166784607716, 0.8753980643052769, 0.8740946413276426, 0.8740246311035813, 0.8752301972373335, 0.8726256618679606, 0.8747544812879018, 0.872249964342169, 0.8730151692812186, 0.874151943826372, 0.874374788662496, 0.8743815051327707, 0.8744322352663829, 0.8703638941489837, 0.8716206249881969, 0.8717527003430737, 0.8754446492151496, 0.8750889524862928, 0.8758728305681086, 0.8729709864605649, 0.8752950961080235, 0.8703281985964131, 0.8715357894002493, 0.8723294068944781, 0.8737909918645486, 0.875082584847458, 0.8761585844387905, 0.8744339849836539, 0.871740767500077, 0.874996 ...

# %%
# Sanity checks.

print(df_sci.iloc[:,4][200]) # Testing array coordinates.
print(df_sci.iloc[:,5])

print(df_sci.iloc[:,4][0])
print(df_sci.iloc[:,5][0])
# Out:
# 10078.85
# 0      3.705866
# 1       3.59892
# 2      3.621976
# 3      3.597713
# 4      3.601891
#          ...
# 598    5.858798
# 599    5.867299
# 600    5.885026
# 601    5.870439
# 602    5.864769
# Name: Flux error, Length: 603, dtype: object
# 12844.825
# 3.7058655000000003

# %%
# I need to divide science star times.

# %%
ratio_45 = []
error_ratio_45 = []

for i in range(603):
    ratio_45.append(df_sci.iloc[:,4][i]/flux_mean_45[i])
    error_ratio_45.append((df_sci.iloc[:,4][i]/flux_mean_45[i])*np.sqrt((df_sci.iloc[:,5][i]/df_sci.iloc[:,4][i])**2 + (error_mean_45[i]/flux_mean_45[i])**2))

print(ratio_45)
print(error_ratio_45)

print('Complete.')
# Out:
# [6.195702710880566, 6.205271200063291, 6.2118513290273585, 6.216683141933284, 6.2186848465422475, 6.194562078021716, 6.2016077700428225, 6.214972618539367, 6.201916772875663, 6.226100958595679, 6.224682524025037, 6.175590999825582, 6.175564525200832, 6.2088486228156805, 6.194785736680702, 6.213415795558119, 6.171375080936464, 6.197701569335708, 6.199426914396245, 6.2054062357100985, 6.184228125725647, 6.1616737145375495, 6.193489166022398, 6.183934633549682, 6.1945119365673404, 6.198942526206054, 6.21786010158129, 6.212686151808884, 6.192343169349959, 6.22373478657469, 6.206226281446942, 6.201816981880835, 6.219153453297635, 6.223107860494924, 6.155625836860928, 6.240059047058992, 6.194999875356172, 6.231967762585629, 6.200866567698226, 6.234480466213683, 6.196793084235373, 6.207635763397475, 6.188439499585721, 6.18998588311418, 6.1798793930196325, 6.19705093151531, 6.177260293608207, 6.214955821648833, 6.2181577058826445, 6.225210485423035, 6.246085397276422, 6.2204991884453396, 6.193962045532215, 6.197349573198513, 6.205914505952258, 6.212159251695394, 6.208534274567238, 6.198281044230819, 6.182480365413404, 6.21954909477816, 6.197889387058157, 6.1953241738574425, 6.1922286950679775, 6.186030500036989, 6.199606772946336, 6.235516806637589, 6.198615746130167, 6.216259070746107, 6.231381747430008, 6.233001596666914, 6.208971827409786, 6.2066376291149, 6.184517855437371, 6.217140853098908, 6.2029226941280164, 6.229300798100374, 6.207984906049621, 6.20086206019993, 6.2057053879268285, 6.175553960791825, 6.214966196272542, 6.177453089922408, 6.2196970243402685, 6.21197130206566, 6.186874563107921, 6.187307555968047, 6.199215597542635, 6.1681197447129605, 6.19809809208841, 6.231786457581065, 6.217599059359209, 6.236227399237629, 6.208976783195838, 6.193139529418112, 6.204960374162768, 6.214815861894659, 6.201617914227747, 6.171938552644843, 6.187549453425982, 6.207957213398649, 6.2007292741520645, 6.223571338476432, 6.2063131488123755, 6.187080646551115, 6.1984598697324635, 6.20689504341123, 6.194735309880269, 6.179034725316703, 6.227863413086083, 6.232840401185861, 6.1844866099209685, 6.176817946813877, 6.159854766598186, 6.212454215278588, 6.211587472112797, 6.162464342311367, 6.192716842861232, 6.205967176234449, 6.168679322895316, 6.170108054315129, 6.168489199191625, 6.187527452776286, 6.148081193995843, 6.17433759958346, 6.208750888108099, 6.173107843271766, 6.130191841298837, 6.185887381365009, 6.123599727595293, 6.109201409819579, 6.089107831357338, 6.107013655692412, 6.1337568411673695, 6.130129881386439, 6.125813805388643, 6.11950569794701, 6.122643493504346, 6.08515486494513, 6.097079507679128, 6.1234098116493065, 6.142854332043517, 6.106323357920544, 6.081973106439862, 6.097806911920338, 6.088509793221145, 6.0782924846195785, 6.0848134131507345, 6.071442188309038, 6.106391747726425, 6.069228389781639, 6.0888835744778635, 6.066372995903658, 6.066602126677415, 6.068238687416879, 6.0604165681697655, 6.098819250476259, 6.011882813126675, 6.0767398109816355, 6.042108703130812, 6.033738883199186, 6.089277621405629, 6.021625894170037, 6.057435975019148, 6.029462089155067, 6.0260721384726725, 6.053572760849018, 6.037807398657145, 6.049075543399044, 6.038933693634636, 6.071121174401947, 6.011859729839239, 6.060269008186328, 6.039202432105355, 6.0259903670395705, 6.037816427486803, 6.063828284547753, 6.056035867721604, 6.019541382398196, 6.033312830745217, 6.045983593361028, 6.06651101249454, 6.023776879681982, 6.054059794005274, 6.030045610577051, 6.04678177480352, 6.002465191082877, 6.074485231957369, 6.04512056320885, 6.054172774838323, 6.024028641045118, 6.060129070632773, 5.994202377139748, 6.065625109047159, 6.06142145906072, 6.0955580070902915, 6.040631279166255, 6.0440932178407, 6.0315939622362205, 6.064443533616514, 6.041519469630437, 6.073610078253051, 6.038475203076915, 6.062774020553354, 6.069792268354703, 6.024896855588273, 6.058398177114216, 6.06009782112062, 6.06795524494107, 6.040818668652662, 6.0735477753301605, ...
# [0.003112214210298411, 0.0039451039940504124, 0.003951342837992501, 0.003940034165089802, 0.003946358505910137, 0.003929333739195472, 0.003942676719650934, 0.003943893842039557, 0.003928567978256164, 0.003935206427620292, 0.003923214181804589, 0.003899684181576446, 0.003909330916774875, 0.0039261931507138005, 0.003904390216210971, 0.003919346101564941, 0.00390706599905143, 0.003913461425209344, 0.003921571609603274, 0.00391045023013051, 0.0038911152646077776, 0.003872029328479441, 0.00389976501478224, 0.0038941528839694026, 0.0039056944693771746, 0.003912077071194863, 0.003922357827598726, 0.003907135439011627, 0.0038945315643498313, 0.003933236458701091, 0.003917123714764166, 0.003920817732735934, 0.003918918905552069, 0.003925486816600981, 0.003884058496517081, 0.003950954478735537, 0.003909426780698876, 0.00389297491470545, 0.003906786818390843, 0.004148451950058719, 0.0039115110372705, 0.0038971657199699875, 0.0038953228459427617, 0.0039016042747089725, 0.003888880615857764, 0.003909820225559406, 0.0038947482436459805, 0.003930371509362468, 0.003926509016146309, 0.003926381641378694, 0.003930374708711293, 0.003914311600256237, 0.003900169598949506, 0.003909876661649371, 0.003928825013078517, 0.0039186728125244095, 0.003911507339164392, 0.003907125111516307, 0.0038875939888806453, 0.003918989003517214, 0.0039045151776280406, 0.0039105629256494245, 0.0038957108202885703, 0.0038951737418668644, 0.0039052966405532332, 0.0039460752212388, 0.003917661330236568, 0.003921824870151447, 0.0039403899653116265, 0.003914921496477486, 0.003917466187020498, 0.003918419533146053, 0.003903271325509026, 0.003919236992864637, 0.0038993761192267465, 0.003938887927410196, 0.003918357359140845, 0.003909469662703644, 0.003895703623101367, 0.0038999052357476527, 0.003909234458560512, 0.003892033878307527, 0.00392407548980059, 0.003913857038277837, 0.003916698251832902, 0.0038960234038590224, 0.003916988063196217, 0.0038787035396204445, 0.003911844560971496, 0.003919632372139337, 0.0039106147997465405, 0.003916887030630335, 0.003896154756508471, 0.003900204532816779, 0.003907839556649721, 0.0039031463546390214, 0.003899596349313062, 0.0038765440725953846, 0.0038899058515253003, 0.00391876816079375, 0.0039134356440381065, 0.003907217198017503, 0.0039041538199175536, 0.003892671333191346, 0.0038996434849311967, 0.003915232208017195, 0.0039023875553079327, 0.003892613165861614, 0.003934920213369067, 0.003945319499477806, 0.00391175285105171, 0.003910166642983358, 0.0038868506398465827, 0.003914408770418382, 0.003918519239735851, 0.0038993102160437415, 0.003915440559359207, 0.0039116112579771125, 0.003892632304094625, 0.0038878232418167705, 0.0039029266606256914, 0.0039027567522627975, 0.003884333428450206, 0.003907897073685013, 0.003911402735127448, 0.0039012734215940854, 0.0038729784383531025, 0.0039030349599415725, 0.0038858201756112693, 0.003855734356829912, 0.0038512253513541513, 0.003850438240277992, 0.003880829190300627, 0.003867931843429689, 0.0038635390109802914, 0.0038680236107864053, 0.0038738162125234255, 0.0038424202650347555, 0.0038558281044846934, 0.003868262457824405, 0.0038859659489243904, 0.0038669150250639655, 0.003856643754752385, 0.0038606487497206293, 0.0038616299643669774, 0.003843628634213083, 0.003861380964734798, 0.0038525338103501607, 0.0038618209801075326, 0.0038500961357689246, 0.003855166418138557, 0.003848702346116618, 0.0038519360803583183, 0.003845218327437892, 0.0038490350612504247, 0.003871025468569367, 0.003818300832286094, 0.0038528273189219015, 0.0038254870103725065, 0.0038340733845946737, 0.0038642395052051796, 0.0038346410724777714, 0.0038533005532724886, 0.003828789130008335, 0.00382682892976614, 0.003860300573328863, 0.003840883867011707, 0.0038463314178168416, 0.0038399274382401173, 0.0038633399289468334, 0.0038138739186880455, 0.0038510716301902058, 0.003851036391691061, 0.003828150848393248, 0.003832759305321379, 0.0038625051408361978, 0.003863849383891243, 0.0038370766261773474, 0.003834080192506049, 0.003 ...
# Complete.

# %%
# Write out data to a text file.

os.chdir('/Users/mvguevarra/Desktop/Astronomy/AST443/Lab2/Analysis')

outfile = open('4.5_Output_Text.txt','w')

outfile.write('Index' + ' ' + 'Time' + ' ' + 'Science flux' + ' ' + 'Science flux error' + ' ' + 'Weighted mean' + ' ' + 'Ratio' + ' ' + 'Ratio error\n')

for i in range(603):
    outfile.write(str(i) + ' ' + str(ref_times[i]) + ' ' + str(df_sci.iloc[:,4][i]) + ' ' + str(df_sci.iloc[:,5][i]) + ' ' + str(flux_mean_45[i]) + ' ' + str(ratio_45[i]) + ' ' + str(error_ratio_45[i]) + '\n')

# %%
# In order to use the baseline ratio, we need to do it outside transit times.
# Transit Start: 8/31/2022 22:36:14 = 81374
# Transit End: 9/01/2022 00:39:03 = 88743

# Starts after 77th image, or number 77. File numbers start at 0.
# Ends before 337th image, or number 337.

base_ratio_45 = []
base_error_ratio_45 = []

for i in range(603):
    if i < 78:
        base_ratio_45.append(ratio_45[i])
        base_error_ratio_45.append(error_ratio_45[i])
    elif i > 336:
        base_ratio_45.append(ratio_45[i])
        base_error_ratio_45.append(error_ratio_45[i])
    else:
        continue

# WARNING: This outputs ratio_45, but entries 76 to 331 are missing. Thus, base_ratio_45[75] = ratio_45[75]
#          but base_ratio_45[76] = ratio_45[332]

# print(base_ratio_45)
# print(base_error_ratio_45)
print(len(base_ratio_45)) # Yes, we indeed are missing (336 - 77 + 1) = 264 images from 603 total images. Length of 344.
print(len(base_error_ratio_45))

# This gives us the baseline flux ratio between science star and weighted mean of reference star fluxes without exoplanet occulting.

avg_base_flux_ratio = np.mean(base_ratio_45)
error_base_flux_ratio = stats.tstd(base_ratio_45)/np.sqrt(602)

print(avg_base_flux_ratio)
print(error_base_flux_ratio)

frac_occlusion_science_45 = []
error_frac_occlusion_science_45 = []

# print(ratio_45)

for j in range(603):
    frac_occlusion_science_45.append(ratio_45[j]/avg_base_flux_ratio)
    error_frac_occlusion_science_45.append(frac_occlusion_science_45[j]*np.sqrt((error_ratio_45[j]/ratio_45[j])**2 + (error_base_flux_ratio/avg_base_flux_ratio)**2))

#print(frac_occlusion_science_45)
print(len(frac_occlusion_science_45))
# Out:
# 344
# 344
# 6.178850356533488
# 0.001734547300121419
# 603

# %%
flux_20s_45 = []
flux_12s_45 = []
flux_10s_45 = []

for i in range(603):
    if i < 333:
        flux_20s_45.append(frac_occlusion_science_45[i])
    elif i > 447:
        flux_12s_45.append(frac_occlusion_science_45[i])
    else:
        flux_10s_45.append(frac_occlusion_science_45[i])

flux_20s_avg_45 = np.mean(flux_20s_45)
flux_12s_avg_45 = np.mean(flux_12s_45)
flux_10s_avg_45 = np.mean(flux_10s_45)

flux_20s_sum_error_45 = 0
flux_12s_sum_error_45 = 0
flux_10s_sum_error_45 = 0

for k in range(603):
    if k < 333:
        flux_20s_sum_error_45 += (flux_20s_45[k]-flux_20s_avg_45)**2
    elif k > 447:
        flux_12s_sum_error_45 += (flux_12s_45[k-448]-flux_12s_avg_45)**2
    else:
        flux_10s_sum_error_45 += (flux_10s_45[k-333]-flux_10s_avg_45)**2

flux_20s_avg_error_45 = np.sqrt(flux_20s_sum_error/(603*602))
flux_12s_avg_error_45 = np.sqrt(flux_12s_sum_error/(603*602))
flux_10s_avg_error_45 = np.sqrt(flux_10s_sum_error/(603*602))
    
#new_frac_45 = []
#new_frac_err_45 = []
#
#for j in range(603):
#    if j < 333:
#        new_frac_45.append(frac_occlusion_science_45[j]/flux_20s_avg_45)
#        new_frac_err_45.append((frac_occlusion_science_45[j]/flux_20s_avg_45)*np.sqrt((error_frac_occlusion_science_45[j]/frac_occlusion_science_45[j])**2 +(flux_20s_avg_error_45/flux_20s_avg_45)**2))
#        
#    elif j > 447:
#        new_frac_45.append(frac_occlusion_science_45[j]/flux_12s_avg_45)
#        new_frac_err_45.append((frac_occlusion_science_45[j]/flux_12s_avg_45)*np.sqrt((error_frac_occlusion_science_45[j]/frac_occlusion_science_45[j])**2 +(flux_12s_avg_error_45/flux_12s_avg_45)**2))
#    else:
#        new_frac_45.append(frac_occlusion_science_45[j]/flux_10s_avg_45)
#        new_frac_err_45.append((frac_occlusion_science_45[j]/flux_10s_avg_45)*np.sqrt((error_frac_occlusion_science_45[j]/frac_occlusion_science_45[j])**2 +(flux_10s_avg_error_45/flux_10s_avg_45)**2))

# %%
#print(new_frac_45[0])
print(frac_occlusion_science_45[0])
print(flux_20s_avg_45)
# Out:
# 1.0027274255524343
# 0.9896585347798594

# %%
# Before 78, after 336.

oh_my_god_ANOTHER_CORRECTION = []
oh_my_god_ITS_TIME = []

for i in range(603):
    if i < 78:
        oh_my_god_ANOTHER_CORRECTION.append(frac_occlusion_science_45[i])
        oh_my_god_ITS_TIME.append(Time(ref_times[i]).mjd)
    if i > 336:
        oh_my_god_ANOTHER_CORRECTION.append(frac_occlusion_science_45[i])
        oh_my_god_ITS_TIME.append(Time(ref_times[i]).mjd)

#print(oh_my_god_ITS_TIME)
        
slope,intercept = np.polyfit(oh_my_god_ITS_TIME,oh_my_god_ANOTHER_CORRECTION,1)

def variable_correction(x):
    return slope*x + intercept

im_running_outta_names = []

for i in range(603):
    im_running_outta_names.append(variable_correction(dumbtimecrap[i]))

print(slope,intercept)
print(variable_correction(59822))

frac_occlusion_science_45_NEW = []

for i in range(603):
    frac_occlusion_science_45_NEW.append(frac_occlusion_science_45[i]/im_running_outta_names[i])
# Out:
# -0.041596409546136755 2489.423175312832
# 1.0427634438392488

# %%
plt.errorbar(ref_times, frac_occlusion_science_45_NEW, yerr=error_frac_occlusion_science_45, fmt='.', label='Science Star')

#plt.errorbar(dumbtimecrap, frac_occlusion_science_45_NEW, yerr=error_frac_occlusion_science_45, fmt='.', label='Science Star')
plt.title('HD 189733 light curve')
plt.xlabel('Time (hh:mm)')
plt.ylabel('$r_i$ (Unitless)')

index = []

for i in range(603):
    index.append(i)

# %%
plt.errorbar(index,frac_occlusion_science_45_NEW, yerr=error_frac_occlusion_science_45, fmt='.', label='Science Star')
plt.title('HD 189733 light curve')
plt.xlabel('Image Index (Unitless)')
plt.ylabel('$r_i$ (Unitless)')

blah1 = []
blah2 = []
blah3 = []

for i in range(603):
    if i < 110:
        blah1.append(frac_occlusion_science_45_NEW[i])
    elif i > 350:
        blah3.append(frac_occlusion_science_45_NEW[i])
    elif 160 < i and i < 290:
        blah2.append(frac_occlusion_science_45_NEW[i])
    else:
        continue

# %% [markdown]
# Before transit: 0 - 100
# During transit: 175 - 275
# After transit: 375 - 603
#
# Filter out outliers from 1:30 AM onwards. Ratio ranges from 0.99 to 1.01.

# %%
type(ref_times[0])
dumbtimecrap = Time(ref_times).mjd
print(dumbtimecrap)
# Out:
# [59822.9155027  59822.91607492 59822.91997241 59822.92026133
#  59822.92055793 59822.92085281 59822.92114227 59822.92143367
#  59822.92173056 59822.92202734 59822.92232345 59822.92261216
#  59822.92290072 59822.9231953  59822.92349225 59822.92378786
#  59822.92408544 59822.92438177 59822.92467201 59822.92496818
#  59822.9252558  59822.92554205 59822.92582855 59822.92611486
#  59822.92640118 59822.92668708 59822.92697345 59822.92726012
#  59822.92754657 59822.92783325 59822.92811935 59822.92840602
#  59822.92869494 59822.92899016 59822.92928598 59822.92958277
#  59822.92987926 59822.93017578 59822.93047315 59822.93077062
#  59822.93106792 59822.93135689 59822.9316465  59822.93194105
#  59822.93223531 59822.93253117 59822.93282381 59822.93311956
#  59822.93341447 59822.93370998 59822.93400781 59822.93430427
#  59822.93460009 59822.93489633 59822.93519259 59822.93548933
#  59822.935786   59822.93607757 59822.93637189 59822.93666639
#  59822.93696103 59822.93725505 59822.93754821 59822.93784326
#  59822.93813824 59822.93843284 59822.9387283  59822.93902277
#  59822.93931736 59822.93961177 59822.939907   59822.940201
#  59822.94049487 59822.94078932 59822.94108346 59822.94137769
#  59822.94167251 59822.94196781 59822.94226256 59822.94255792
#  59822.94285187 59822.94314572 59822.94344106 59822.94373288
#  59822.94402772 59822.94432211 59822.94461712 59822.94491133
#  59822.94520601 59822.94550134 59822.94579507 59822.94609025
#  59822.94638437 59822.94667434 59822.94696912 59822.94726389
#  59822.94755819 59822.94785366 59822.94814699 59822.94844041
#  59822.94873539 59822.94902936 59822.94932315 59822.94961668
#  59822.949911   59822.95020558 59822.95049992 59822.9507952
#  59822.95108968 59822.9513848  59822.95167913 59822.95197339
#  59822.95226832 59822.95256355 59822.95285824 59822.95315328
#  59822.95344859 59822.95374171 59822.9540364  59822.9543306
#  59822.95462525 59822.95492037 59822.95521517 59822.95550944
#  59822.95580308 59822.95609707 59822.95639138 59822.9566833
#  59822.95697777 59822.95727307 59822.95756721 59822.95786065
#  59822.95815412 59822.95844834 59822.95874304 59822.95903775
#  59822.95933171 59822.9596244  59822.9599201  59822.96021517
#  59822.96050993 59822.96080574 59822.9611012  59822.96139568
#  59822.9616906  59822.96198508 59822.96227985 59822.96257475
#  59822.96286965 59822.96316407 59822.96345822 59822.96375271
#  59822.96404738 59822.96434234 59822.96463579 59822.96493029
#  59822.9652252  59822.96551953 59822.96581446 59822.96610911
#  59822.96640417 59822.96669875 59822.96699422 59822.96728907
#  59822.96758492 59822.96788065 59822.96817521 59822.96847002
#  59822.96876394 59822.96905682 59822.96935081 59822.96964473
#  59822.96993819 59822.9702326  59822.97052675 59822.97082119
#  59822.97111567 59822.9714086  59822.97170249 59822.97199668
#  59822.97229089 59822.97258542 59822.97288078 59822.9731744
#  59822.97346898 59822.97376392 59822.9740506  59822.97434365
#  59822.97463707 59822.97493169 59822.97522557 59822.97551987
#  59822.97581405 59822.97610666 59822.97640109 59822.97669481
#  59822.97698741 59822.97728139 59822.97757416 59822.97786888
#  59822.9781624  59822.9784573  59822.97875196 59822.97904616
#  59822.97933977 59822.97963363 59822.97992824 59822.98022187
#  59822.98051552 59822.98080921 59822.9811031  59822.98139757
#  59822.98169181 59822.98198553 59822.98227946 59822.98257251
#  59822.98286584 59822.98315667 59822.98344992 59822.98374285
#  59822.98403664 59822.98432963 59822.98462378 59822.98491883
#  59822.98521311 59822.98550672 59822.98580133 59822.98609527
#  59822.98638938 59822.98668274 59822.98697637 59822.98727028
#  59822.98756488 59822.98785825 59822.98815263 59822.9884464
#  59822.98874036 59822.98903479 59822.98932991 59822.98962272
#  59822.98991508 59822.99020855 59822.99050247 59822.99079706
#  59822.99109234 59822.99138781 59822.99168125 59822.99197692
#  59822.99227115 59822.99256612 59822.99286056 59822.99315476
#  59822.99344678 59822.99374086 59822.99403399 59822.99432747
#  59822.99462182 59822.99491622 59822.99521117 59822.99550314
#  59822.99579584 59822.99608999 59822.996385   59822.9966789
#  59822.99697321 59822.99726718 59822.99756046 59822.99785398
#  59822.99814838 59822.99844274 59822.99873711 59822.99903191
#  59822.99932649 59822.9996202  59822.99991589 59823.00021041
#  59823.00050549 59823.00079963 59823.00109461 59823.00138994
#  59823.00167712 59823.00197125 59823.0022645  59823.00255947
#  59823.00285398 59823.00314949 59823.00344326 59823.00373821
#  59823.00403382 59823.00432812 59823.00462418 59823.00491632
#  59823.00521157 59823.00550723 59823.00580222 59823.00609737
#  59823.00639233 59823.00668786 59823.00698134 59823.00727587
#  59823.00756941 59823.00786477 59823.00815969 59823.00845502
#  59823.00874958 59823.009044   59823.00933872 59823.00963147
#  59823.00992625 59823.01022022 59823.0105161  59823.01081021
#  59823.01110591 59823.01140049 59823.01169613 59823.0119911
#  59823.01228559 59823.01257764 59823.01287227 59823.01316569
#  59823.01345985 59823.01374709 59823.01404062 59823.01433441
#  59823.01462744 59823.01492134 59823.01521208 59823.01550502
#  59823.01579868 59823.01609157 59823.01638624 59823.01668014
#  59823.01697472 59823.01945909 59823.02017047 59823.0203478
#  59823.02052684 59823.03173064 59823.03190823 59823.03208579
#  59823.03226459 59823.03244162 59823.03262024 59823.03279905
#  59823.03297708 59823.03315591 59823.03351088 59823.03368985
#  59823.03386932 59823.03404799 59823.03422648 59823.03440449
#  59823.03458326 59823.03476163 59823.03493944 59823.03511785
#  59823.03529634 59823.03547453 59823.03565376 59823.03583302
#  59823.03601281 59823.03619204 59823.0363711  59823.03654293
#  59823.03671954 59823.03689831 59823.03707646 59823.03725626
#  59823.03743591 59823.03761406 59823.03779071 59823.03796926
#  59823.0381481  59823.03832634 59823.03850484 59823.03868391
#  59823.03886295 59823.03904186 59823.03922057 59823.03939917
#  59823.03957029 59823.03974916 59823.03992718 59823.04010576
#  59823.04028407 59823.04046295 59823.0406414  59823.04082015
#  59823.04099856 59823.04117666 59823.04135486 59823.04153361
#  59823.04171069 59823.04189046 59823.04206984 59823.04224934
#  59823.04242831 59823.04260795 59823.04278701 59823.04296603
#  59823.04314365 59823.04332067 59823.04349918 59823.04367765
#  59823.04385536 59823.0440337  59823.04421275 59823.04439122
#  59823.04457031 59823.0447478  59823.04492613 59823.04510479
#  59823.04528361 59823.04546075 59823.0456366  59823.04581604
#  59823.04599524 59823.04617216 59823.04635115 59823.04652949
#  59823.04670791 59823.04688568 59823.04706353 59823.04724023
#  59823.04741887 59823.04759694 59823.04777617 59823.04795462
#  59823.04813304 59823.04831205 59823.04849069 59823.04867045
#  59823.04884904 59823.04902837 59823.04920762 59823.04938706
#  59823.04956574 59823.0497374  59823.04991609 59823.05009443
#  59823.05027163 59823.05045015 59823.05062301 59823.05080209
#  59823.0509814  59823.05116052 59823.05133932 59823.05151828
#  59823.05179736 59823.05199921 59823.05219904 59823.05240036
#  59823.05260042 59823.05280253 59823.05300498 59823.05320728
#  59823.05340898 59823.05361103 59823.0538135  59823.05401582
#  59823.05421808 59823.05442035 59823.05462302 59823.05482383
#  59823.05502678 59823.05522898 59823.05543175 59823.05563451
#  59823.05583736 59823.05603975 59823.05624287 59823.05644513
#  59823.05664797 59823.0568508  59823.05705315 59823.05725545
#  59823.05745812 59823.05765938 59823.05786166 59823.05806372
#  59823.05826625 59823.05846809 59823.05867087 59823.05887344
#  59823.05907589 59823.05927905 59823.05948123 59823.05968347
#  59823.05988697 59823.06008824 59823.06029079 59823.06049279
#  59823.06069372 59823.06089654 59823.06109904 59823.06130214
#  59823.06150476 59823.06170819 59823.06191082 59823.06211295
#  59823.06231588 59823.06251802 59823.06272012 59823.06292317
#  59823.06312525 59823.06332714 59823.06352872 59823.06373145
#  59823.0639338  59823.06413652 59823.06433968 59823.06453361
#  59823.0647356  59823.06493759 59823.06513919 59823.06534096
#  59823.06554303 59823.06574547 59823.06594712 59823.06614965
#  59823.06635219 59823.06655476 59823.06675676 59823.06695888
#  59823.06716123 59823.06736344 59823.06756603 59823.06776753
#  59823.06796933 59823.06817113 59823.06837348 59823.06857591
#  59823.06877795 59823.06897976 59823.0691801  59823.0693808
#  59823.0695812  59823.06978139 59823.06998208 59823.07018311
#  59823.07038513 59823.07058699 59823.07078909 59823.07099029
#  59823.07119205 59823.07139387 59823.07159542 59823.07179762
#  59823.07199959 59823.07220106 59823.07240274 59823.07260456
#  59823.07280593 59823.07300661 59823.07320807 59823.07340978
#  59823.07360971 59823.07381064 59823.0740122  59823.07421308
#  59823.07441332 59823.07461466 59823.07481646 59823.07501868
#  59823.0752206  59823.07542259 59823.07562421 59823.07582625
#  59823.07602698 59823.0762284  59823.07642727 59823.07662941
#  59823.07683263 59823.07703328 59823.07723434 59823.07743507
#  59823.07763532 59823.07783733 59823.07803785 59823.07824032
#  59823.0784411  59823.07864362 59823.07884476 59823.07904741
#  59823.07924876 59823.07944947 59823.07965066 59823.07985285
#  59823.08005442 59823.08025633 59823.08045793 59823.08065789
#  59823.08085861 59823.08105917 59823.08125837 59823.08145941
#  59823.08166157 59823.08186409 59823.08206631 59823.0822664
#  59823.08246453 59823.08266307 59823.0828639 ]

# %%
stats.tstd([error_frac_occlusion_science_45[5*0],error_frac_occlusion_science_45[5*0+1],error_frac_occlusion_science_45[5*0+2],error_frac_occlusion_science_45[5*0+3],error_frac_occlusion_science_45[5*0+4]])
# Out:
# 5.4197993784559076e-05

# %% [markdown]
# Star is variable, excise the transit data, linear fit to the leftovers, divide the entire curve by the linear fit.

# %%
frac_occlusion_science_45_binned = []
ref_times_float = []
ref_times_binned = []
error_frac_occlusion_science_45_binned = []

def mean_binner_boy(array,ele,length): # ele is an element of array, length + ele </= len(array)
    temp_array = []
    for i in range(length):
        temp_array.append(array[ele+i])
    return np.mean(temp_array)

def binner_code(array,ele,length):
    new_new_temp_array = []
    for k in range(length):
        new_new_temp_array.append(array[ele+k])
    return new_new_temp_array
    
print(binner_code([2,4,4,5,3,6,3,5,5],0,3))

def why_is_this_my_life_err(array,ele,length):
    return stats.tstd(binner_code(array,ele,length))/np.sqrt(length)
#    new_temp_array = []
#    auxiliary_var = 0
#    for j in range(length):
#        auxiliary_var += (array[ele+j] - mean_binner_boy(array,ele,length))**2
#    return np.sqrt(auxiliary_var/(len(array)*(len(array))))

print(mean_binner_boy([2,4,4,5,3,6,3,5,5],0,3))

bin_length = 10

for i in range(int(np.floor(600/bin_length))):
    frac_occlusion_science_45_binned.append(mean_binner_boy(frac_occlusion_science_45_NEW,bin_length*i,bin_length))
    ref_times_binned.append(mean_binner_boy(dumbtimecrap,bin_length*i,bin_length))
    error_frac_occlusion_science_45_binned.append(why_is_this_my_life_err(frac_occlusion_science_45_NEW,bin_length*i,bin_length))

plt.errorbar(ref_times_binned, 
             frac_occlusion_science_45_binned, 
             yerr=error_frac_occlusion_science_45_binned, 
             fmt='.',
             label='Science Star')
plt.xlabel('Time (MJD)')
plt.ylabel('$r_i$ (Unitless)')

#print(error_frac_occlusion_science_45_binned)

before_binned_data = []
during_binned_data = []
after_binned_data = []

for i in range(101):
    before_binned_data.append(frac_occlusion_science_45[i])
for j in range(175,276):
    during_binned_data.append(frac_occlusion_science_45[j])
for k in range(375,603):
    after_binned_data.append(frac_occlusion_science_45[k])
    
before_avg_45_binned = np.mean(before_binned_data)
during_avg_45_binned = np.mean(during_binned_data)
after_avg_45_binned = np.mean(after_binned_data)

before_avg_45_binned_error = stats.tstd(before_data)/np.sqrt(len(before_binned_data))
during_avg_45_binned_error = stats.tstd(during_data)/np.sqrt(len(during_binned_data))
after_avg_45_binned_error = stats.tstd(after_data)/np.sqrt(len(after_binned_data))

print(before_avg_45_binned,during_avg_45_binned,after_avg_45_binned)
print(before_avg_45_binned_error,during_avg_45_binned_error,after_avg_45_binned_error)

print(before_avg_45_binned - before_avg_45_binned_error, after_avg_45_binned + after_avg_45_binned_error)

# The before and after fluxes match within uncertainty.

print('Transit depth (relative to earlier mean):',before_avg_45_binned - during_avg_45_binned)
print('Error in transit depth (relative to earlier mean):', np.sqrt(before_avg_45_binned_error**2 + during_avg_45_binned_error**2))
print('Transit depth (relative to later mean):', after_avg_45_binned - during_avg_45_binned)
print('Error in transit depth (relative to later mean):',np.sqrt(after_avg_45_binned_error**2 + during_avg_45_binned_error**2))
# Out:
# [2, 4, 4]
# 3.3333333333333335
# 1.0040197983447752 0.9781414085348114 0.9989183306982954
# 0.00028995209855131745 0.00035114949761929016 0.00047892574941603444
# 1.0037298462462239 0.9993972564477114
# Transit depth (relative to earlier mean): 0.02587838980996382
# Error in transit depth (relative to earlier mean): 0.0004553879545317298
# Transit depth (relative to later mean): 0.020776922163484035
# Error in transit depth (relative to later mean): 0.0005938651725198153

# %%
before_data = []
during_data = []
after_data = []

for i in range(101):
    before_data.append(frac_occlusion_science_45_NEW[i])
for j in range(175,276):
    during_data.append(frac_occlusion_science_45_NEW[j])
for k in range(375,603):
    after_data.append(frac_occlusion_science_45_NEW[k])

before_avg_45 = np.mean(blah1)
during_avg_45 = np.mean(blah2)
after_avg_45 = np.mean(blah3)

before_avg_45_error = stats.tstd(blah1)/np.sqrt(110)
during_avg_45_error = stats.tstd(blah2)/np.sqrt(229)
after_avg_45_error = stats.tstd(blah3)/np.sqrt(253)

print(before_avg_45, during_avg_45, after_avg_45)
print(before_avg_45_error, during_avg_45_error, after_avg_45_error)

print(before_avg_45 - before_avg_45_error, after_avg_45 + after_avg_45_error)

# Before and after, the means match within uncertainty. Measure transit depth relative to average of before and after.

transit_depth = (before_avg_45+after_avg_45)/2 - during_avg_45
transit_depth_err = np.sqrt(during_avg_45_error**2 + 0.25*(before_avg_45_error**2 + after_avg_45_error**2))

print(transit_depth, 'p/m', transit_depth_err)

planet_radius = np.sqrt(transit_depth)*0.805*9.73116
planet_radius_err = transit_depth_err*0.805*9.73116/(2*np.sqrt(transit_depth))

print(planet_radius, 'p/m', transit_depth_err)

deviation = np.abs(transit_depth - 0.02427)/np.sqrt(transit_depth_err**2 + 0.00005**2)
print(deviation, 'sigma deviation.')
# Out:
# 1.0001951743362774 0.9764201253327187 1.0000311186200797
# 0.00027875055496372214 0.00022407262052947442 0.00045549812911019517
# 0.9999164237813136 1.00048661674919
# 0.02369302114545979 p/m 0.00034857372771024154
# 1.2057873259573073 p/m 0.00034857372771024154
# 1.6384857700526405 sigma deviation.

# %% [markdown]
# HD 189733 has a radius of 0.805 solar radii, and HD 189733b has a radius of 1.138 jovian radii.
# 1 solar radius = 9.73116 jovian radii.
# Transit depth of about 0.02353, with an error of 0.00034, planetary radius of 1.2016 jovian radii, with an error of 0.0003 jovian radii.
#
# Begins: ~10:45 PM
#
# Ends: ~12:45 PM
#
# Actually begins: 10:36:14 PM
#
# Actually ends: 12:39:03 PM

# %% [markdown]
# 5.0 - Analysis and Discussion

# %% [markdown]
# It seems that the flux before the transit compared to the flux after the transit is remarably more stable, and centered around 1.05. Whereas the flux after fluctuates to a greater extent , and is centered closer to 1.0. It is possible that atmospheric effects contributed to the fluctuations experienced post-transit. Also, since exposure time is halved later on the night, it is possible that we see increased uncertainty.
#
# It was then discovered that HD 1897833 is a variable star, BY Draconis. This could explain the different brightness before and after.
#
# The differences are not so remarkable as to require a constant line for fitting.

# %% [markdown]
# Here, we see an evident transit depth of around 2%.
#
# Transit time variations occured due to extrapolating from data ~10 years ago, but changes in orbital period may change this.
